# %% [markdown]
# # Execute PCP generic pipeline step by step

# %% [markdown]
# ## Imports

# %%
from pathlib import Path

from pipecraft.backend.snakemake import SnakeMakeBackend, SnakeMakeConfig

from starrynight.experiments.common import AcquisitionOrderType, ImageFrameType
from starrynight.experiments.pcp_generic import PCPGeneric, PCPGenericInitConfig
from starrynight.modules.analysis.analysis_cp import AnalysisInvokeCPModule
from starrynight.modules.analysis.analysis_cppipe import AnalysisGenCPPipeModule
from starrynight.modules.analysis.analysis_load_data import (
    AnalysisGenLoadDataModule,
)
from starrynight.modules.cp_illum_apply.apply_cp import (
    CPApplyIllumInvokeCPModule,
)
from starrynight.modules.cp_illum_apply.apply_cppipe import (
    CPApplyIllumGenCPPipeModule,
)
from starrynight.modules.cp_illum_apply.apply_load_data import (
    CPApplyIllumGenLoadDataModule,
)

# cp_illum_calc
from starrynight.modules.cp_illum_calc.calc_cp import CPCalcIllumInvokeCPModule
from starrynight.modules.cp_illum_calc.calc_cppipe import (
    CPCalcIllumGenCPPipeModule,
)
from starrynight.modules.cp_illum_calc.calc_load_data import (
    CPCalcIllumGenLoadDataModule,
)

# cp_segcheck
from starrynight.modules.cp_segcheck.segcheck_cp import CPSegcheckInvokeCPModule
from starrynight.modules.cp_segcheck.segcheck_cppipe import (
    CPSegcheckGenCPPipeModule,
)
from starrynight.modules.cp_segcheck.segcheck_load_data import (
    CPSegcheckGenLoadDataModule,
)

# inventory and index
from starrynight.modules.gen_index import GenIndexModule
from starrynight.modules.gen_inv import GenInvModule
from starrynight.modules.sbs_illum_apply.apply_cp import (
    SBSApplyIllumInvokeCPModule,
)
from starrynight.modules.sbs_illum_apply.apply_cppipe import (
    SBSApplyIllumGenCPPipeModule,
)
from starrynight.modules.sbs_illum_apply.apply_load_data import (
    SBSApplyIllumGenLoadDataModule,
)
from starrynight.modules.sbs_illum_calc.calc_cp import (
    SBSCalcIllumInvokeCPModule,
)
from starrynight.modules.sbs_illum_calc.calc_cppipe import (
    SBSCalcIllumGenCPPipeModule,
)
from starrynight.modules.sbs_illum_calc.calc_load_data import (
    SBSCalcIllumGenLoadDataModule,
)
from starrynight.modules.sbs_preprocess.preprocess_cp import (
    SBSPreprocessInvokeCPModule,
)  # noqa: E501
from starrynight.modules.sbs_preprocess.preprocess_cppipe import (
    SBSPreprocessGenCPPipeModule,
)
from starrynight.modules.sbs_preprocess.preprocess_load_data import (
    SBSPreprocessGenLoadDataModule,
)
from starrynight.schema import DataConfig

# %% [markdown]
# ## Setup dataset paths
# These paths are required for creating the `DataConfig` object and configure the execution backend.

# %%
dataset_path = Path("../../../scratch/fix_s1_input")
barcode_csv_path = dataset_path.joinpath("Source1/workspace/metadata/Barcodes.csv")
workspace_path = Path("../../../scratch/fix_s1_output/workspace")
exec_runs = Path("../../../scratch/fix_s1_runs")
exec_mounts = Path("../../../scratch/fix_s1_mounts")

# %% [markdown]
# ## Create data config

# %%
data_config = DataConfig(
    dataset_path=dataset_path,
    storage_path=dataset_path,
    workspace_path=workspace_path,
)

# %% [markdown]
# ## Create execution engine config config
# Here we are creating a `SnakeMakeBackend` config.
# We can also use other backends like `NextflowBackend` and `AWSBatchBackend`

# %%
backend_config = SnakeMakeConfig(
    use_fluent_bit=False, print_exec=True, background=False
)

# %% [markdown]
# ## Configure the generate inventory module
# This module is special and doesn't require an experiment for configuration

# %%
gen_inv_mod = GenInvModule(data_config)
exec_backend = SnakeMakeBackend(
    gen_inv_mod.pipe, backend_config, exec_runs / "run001", exec_mounts
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                   count
# ------------------  -------
# all                       1
# generate_inventory        1
# total                     2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:23:53 2025]
# localrule generate_inventory:
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/inventory/inventory.parquet
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight inventory gen -d /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/inventory
# Could not load runstardist
# Could not load runomnipose
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Writing inventory:   0%|          | 0/4 [00:00<?, ?it/s]
#
#
# Writing inventory:   0%|          | 0/4 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Writing inventory:   0%|          | 0/4 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Writing inventory:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Writing inventory: 100%|██████████| 4/4 [00:00<00:00, 31242.49it/s]
# Writing inventory: 100%|██████████| 4/4 [00:00<00:00, 32577.12it/s]A
#
#
#
#
#
#
#
#
#
# Writing inventory:   0%|          | 0/4 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Writing inventory: 100%|██████████| 4/4 [00:00<00:00, 2053.26it/s][A
# Writing inventory: 100%|██████████| 4/4 [00:00<00:00, 1905.64it/s]
# Writing inventory: 100%|██████████| 4/4 [00:00<00:00, 1909.97it/s]
# Writing inventory: 100%|██████████| 4/4 [00:00<00:00, 1950.39it/s]
#
# Writing inventory: 100%|██████████| 4/4 [00:00<00:00, 1794.55it/s]
# Writing inventory: 100%|██████████| 4/4 [00:00<00:00, 1716.69it/s]
# Writing inventory: 100%|██████████| 4/4 [00:00<00:00, 1738.39it/s]
# Writing inventory: 100%|██████████| 4/4 [00:00<00:00, 1742.73it/s]
# Writing inventory: 100%|██████████| 4/4 [00:00<00:00, 1559.37it/s]
# Writing inventory: 100%|██████████| 4/4 [00:00<00:00, 1818.27it/s]
# Writing inventory: 100%|██████████| 4/4 [00:00<00:00, 2055.78it/s]
# Writing inventory: 100%|██████████| 3/3 [00:00<00:00, 6786.90it/s]
# [Sat Jun  7 09:24:01 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:24:01 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/inventory/inventory.parquet
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:24:01 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092353.747203.snakemake.log

# %% [markdown]
# ## Configure the generate index module
# This module is special and doesn't require an experiment for configuration

# %%
gen_ind_mod = GenIndexModule(data_config)
exec_backend = SnakeMakeBackend(
    gen_ind_mod.pipe, backend_config, exec_runs / "run002", exec_mounts
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job               count
# --------------  -------
# all                   1
# generate_index        1
# total                 2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:24:02 2025]
# localrule generate_index:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/inventory/inventory.parquet
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index/index.parquet
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight index gen -i /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/inventory/inventory.parquet -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index
# Could not load runstardist
# Could not load runomnipose
# Generating Index: 1it [00:00, 60.13it/s]
# Unable to parse: {'key': 'fix_s1_input/Source1/workspace/metadata/Barcodes.csv', 'filename': 'Barcodes.csv', 'extension': '.csv', 'prefix': '/Users/shsingh/Documents/GitHub/starrynight/scratch'} because of Unexpected token Token('WORKSPACE', 'workspace') at line 1, column 22.
# Expected one of:
# 	* MINUS
# 	* SPACE
# 	* DIGIT
# 	* UNDERSCORE
# 	* COMMA
# 	* LETTER
# [Sat Jun  7 09:24:08 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:24:08 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index/index.parquet
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:24:08 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092402.814817.snakemake.log

# %% [markdown]
# ## Configure the experiment with the generated index

# %%
index_path = workspace_path / "index/index.parquet"
pcp_exp_init = PCPGenericInitConfig(
    barcode_csv_path=barcode_csv_path.resolve(),
    cp_acquisition_order=AcquisitionOrderType.SNAKE,
    cp_img_frame_type=ImageFrameType.ROUND,
    cp_img_overlap_pct=10,
    sbs_acquisition_order=AcquisitionOrderType.SNAKE,
    sbs_img_frame_type=ImageFrameType.ROUND,
    sbs_img_overlap_pct=10,
    cp_nuclei_channel="DAPI",
    cp_cell_channel="PhalloAF750",
    cp_mito_channel="ZO1AF488",
    cp_custom_channel_map={
        "DAPI": "DNA",
        "ZO1AF488": "ZO1",
        "PhalloAF750": "Phalloidin",
    },
    sbs_nuclei_channel="DAPI",
    sbs_cell_channel="PhalloAF750",
    sbs_mito_channel="ZO1AF488",
    sbs_custom_channel_map={
        "DAPI": "DNA",
        "A": "A",
        "T": "T",
        "G": "G",
        "C": "C",
    },
)
pcp_experiment = PCPGeneric.from_index(index_path, pcp_exp_init.model_dump())

# %%
# Write out the experiment as a json file
experiment_dir = data_config.workspace_path.joinpath("experiment")
experiment_dir.mkdir(parents=True, exist_ok=True)
experiment_dir.joinpath("experiment.json").write_text(
    pcp_experiment.model_dump_json()
)
# Out:
# 1006

# %% [markdown]
# ## Configure the following modules with the experiment
#
# ------------------------------------------------------------------

# %% [markdown]
# ## Step 1: CP calculate illum correction

# %% [markdown]
# ### Gen load data

# %%
cp_calc_illum_load_data_mod = CPCalcIllumGenLoadDataModule(
    data_config, pcp_experiment
)
# Change default value to use legacy pipeline compatible load data
cp_calc_illum_load_data_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    cp_calc_illum_load_data_mod.pipe,
    backend_config,
    exec_runs / "run003",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                           count
# --------------------------  -------
# all                               1
# cp_calc_illum_gen_loaddata        1
# total                             2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:24:09 2025]
# localrule cp_calc_illum_gen_loaddata:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index/index.parquet
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/illum_calc/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight illum calc loaddata -i /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index/index.parquet -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/illum_calc --use_legacy --exp_config /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/experiment/experiment.json
# Could not load runstardist
# Could not load runomnipose
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/illum_calc/completed.txt.
# [Sat Jun  7 09:24:13 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:24:13 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/illum_calc/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:24:13 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092408.991598.snakemake.log

# %% [markdown]
# ### Gen cppipe file

# %%
cp_calc_illum_cppipe_mod = CPCalcIllumGenCPPipeModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
cp_calc_illum_cppipe_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    cp_calc_illum_cppipe_mod.pipe,
    backend_config,
    exec_runs / "run004",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                      count
# ---------------------  -------
# all                          1
# calc_illum_gen_cppipe        1
# total                        2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:24:14 2025]
# localrule calc_illum_gen_cppipe:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/illum_calc/completed.txt
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/illum_calc/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight illum calc cppipe -l /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/illum_calc -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/illum_calc -w /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_calc --use_legacy
# Could not load runstardist
# Could not load runomnipose
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/illum_calc/completed.txt.
# [Sat Jun  7 09:24:19 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:24:19 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/illum_calc/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:24:19 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092414.648465.snakemake.log

# %% [markdown]
# ### Invoke cppipe file

# %%
cp_calc_illum_invoke_mod = CPCalcIllumInvokeCPModule(
    data_config, pcp_experiment
)

exec_backend = SnakeMakeBackend(
    cp_calc_illum_invoke_mod.pipe,
    backend_config,
    exec_runs / "run005",
    exec_mounts,
)
run = exec_backend.run()
run.wait()

# ------------------------------------------------------------------
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                        count
# -----------------------  -------
# all                            1
# cp_calc_illum_invoke_cp        1
# total                          2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:24:20 2025]
# localrule cp_calc_illum_invoke_cp:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/illum_calc/completed.txt, /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/illum_calc/illum_calc_painting.cppipe
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_calc/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight cp -p /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/illum_calc/illum_calc_painting.cppipe -l /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/illum_calc -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_calc
# Could not load runstardist
# Could not load runomnipose
# INFO:cellprofiler_core.utilities.java:Initializing Java Virtual Machine
#   0%|          | 0/1 [00:00<?, ?it/s]INFO:cellprofiler_core.pipeline._pipeline:Times reported are CPU and Wall-clock times for each module
# [ERROR] "loci.formats.in.WlzReader" is not valid.
# [ERROR] "loci.formats.in.IonpathMIBITiffReader" is not valid.
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellB1_PointB1_0000_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq3075.ome.tiff
# Reading IFDs
# Populating metadata
# [WARN] PixelType mismatch: OME=3, TIFF=1
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellB1_PointB1_0000_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq3075.ome.tiff
# Reading IFDs
# Populating metadata
# [WARN] PixelType mismatch: OME=3, TIFF=1
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellB1_PointB1_0000_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq3075.ome.tiff
# Reading IFDs
# Populating metadata
# [WARN] PixelType mismatch: OME=3, TIFF=1
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:26 2025: Image # 1, module LoadData # 1: CPU_time = 1.84 secs, Wall_time = 1.27 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:27 2025: Image # 1, module Resize # 2: CPU_time = 0.03 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:27 2025: Image # 1, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (32948), equivalent to an approximate bitdepth of 15.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:27 2025: Image # 1, module Resize # 4: CPU_time = 0.14 secs, Wall_time = 0.14 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:27 2025: Image # 1, module Resize # 5: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:27 2025: Image # 1, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (13769), equivalent to an approximate bitdepth of 13.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:27 2025: Image # 1, module Resize # 7: CPU_time = 0.19 secs, Wall_time = 0.19 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:27 2025: Image # 1, module Resize # 8: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:27 2025: Image # 1, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65366), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:27 2025: Image # 1, module Resize # 10: CPU_time = 0.47 secs, Wall_time = 0.47 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:28 2025: Image # 1, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:28 2025: Image # 1, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:28 2025: Image # 1, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# [WARN] PixelType mismatch: OME=3, TIFF=1
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellB1_PointB1_0002_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq3077.ome.tiff
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellB1_PointB1_0002_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq3077.ome.tiff
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellB1_PointB1_0002_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq3077.ome.tiff
# Reading IFDs
# Populating metadata
# [WARN] PixelType mismatch: OME=3, TIFF=1
# [WARN] PixelType mismatch: OME=3, TIFF=1
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:28 2025: Image # 2, module LoadData # 1: CPU_time = 0.69 secs, Wall_time = 0.51 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:28 2025: Image # 2, module Resize # 2: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:28 2025: Image # 2, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (20862), equivalent to an approximate bitdepth of 14.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:28 2025: Image # 2, module Resize # 4: CPU_time = 0.16 secs, Wall_time = 0.16 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:28 2025: Image # 2, module Resize # 5: CPU_time = 0.03 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:28 2025: Image # 2, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (8870), equivalent to an approximate bitdepth of 13.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:28 2025: Image # 2, module Resize # 7: CPU_time = 0.18 secs, Wall_time = 0.18 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:29 2025: Image # 2, module Resize # 8: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:29 2025: Image # 2, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (37727), equivalent to an approximate bitdepth of 15.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:29 2025: Image # 2, module Resize # 10: CPU_time = 0.47 secs, Wall_time = 0.47 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:29 2025: Image # 2, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:29 2025: Image # 2, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:29 2025: Image # 2, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# [WARN] PixelType mismatch: OME=3, TIFF=1
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA2_PointA2_0003_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq1028.ome.tiff
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA2_PointA2_0003_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq1028.ome.tiff
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA2_PointA2_0003_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq1028.ome.tiff
# Reading IFDs
# Populating metadata
# [WARN] PixelType mismatch: OME=3, TIFF=1
# [WARN] PixelType mismatch: OME=3, TIFF=1
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:29 2025: Image # 3, module LoadData # 1: CPU_time = 0.64 secs, Wall_time = 0.48 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:30 2025: Image # 3, module Resize # 2: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:30 2025: Image # 3, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (14662), equivalent to an approximate bitdepth of 13.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:30 2025: Image # 3, module Resize # 4: CPU_time = 0.15 secs, Wall_time = 0.16 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:30 2025: Image # 3, module Resize # 5: CPU_time = 0.03 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:30 2025: Image # 3, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (7710), equivalent to an approximate bitdepth of 12.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:30 2025: Image # 3, module Resize # 7: CPU_time = 0.17 secs, Wall_time = 0.18 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:30 2025: Image # 3, module Resize # 8: CPU_time = 0.03 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:30 2025: Image # 3, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (28377), equivalent to an approximate bitdepth of 14.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:30 2025: Image # 3, module Resize # 10: CPU_time = 0.42 secs, Wall_time = 0.42 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:30 2025: Image # 3, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:30 2025: Image # 3, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:30 2025: Image # 3, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# [WARN] PixelType mismatch: OME=3, TIFF=1
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA1_PointA1_0003_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq0003.ome.tiff
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA1_PointA1_0003_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq0003.ome.tiff
# [WARN] PixelType mismatch: OME=3, TIFF=1
# [WARN] PixelType mismatch: OME=3, TIFF=1
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA1_PointA1_0003_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq0003.ome.tiff
# Reading IFDs
# Populating metadata
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:30 2025: Image # 4, module LoadData # 1: CPU_time = 0.59 secs, Wall_time = 0.47 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:31 2025: Image # 4, module Resize # 2: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:31 2025: Image # 4, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (11311), equivalent to an approximate bitdepth of 13.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:31 2025: Image # 4, module Resize # 4: CPU_time = 0.15 secs, Wall_time = 0.15 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:31 2025: Image # 4, module Resize # 5: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:31 2025: Image # 4, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (6201), equivalent to an approximate bitdepth of 12.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:31 2025: Image # 4, module Resize # 7: CPU_time = 0.17 secs, Wall_time = 0.16 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:31 2025: Image # 4, module Resize # 8: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:31 2025: Image # 4, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (25080), equivalent to an approximate bitdepth of 14.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:31 2025: Image # 4, module Resize # 10: CPU_time = 0.40 secs, Wall_time = 0.40 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:32 2025: Image # 4, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:32 2025: Image # 4, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:32 2025: Image # 4, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# [WARN] PixelType mismatch: OME=3, TIFF=1
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellB1_PointB1_0003_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq3078.ome.tiff
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellB1_PointB1_0003_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq3078.ome.tiff
# [WARN] PixelType mismatch: OME=3, TIFF=1
# [WARN] PixelType mismatch: OME=3, TIFF=1
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellB1_PointB1_0003_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq3078.ome.tiff
# Reading IFDs
# Populating metadata
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:32 2025: Image # 5, module LoadData # 1: CPU_time = 0.58 secs, Wall_time = 0.45 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:32 2025: Image # 5, module Resize # 2: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:32 2025: Image # 5, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (10277), equivalent to an approximate bitdepth of 13.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:32 2025: Image # 5, module Resize # 4: CPU_time = 0.15 secs, Wall_time = 0.15 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:32 2025: Image # 5, module Resize # 5: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:32 2025: Image # 5, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (5710), equivalent to an approximate bitdepth of 12.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:32 2025: Image # 5, module Resize # 7: CPU_time = 0.16 secs, Wall_time = 0.16 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:33 2025: Image # 5, module Resize # 8: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:33 2025: Image # 5, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (21376), equivalent to an approximate bitdepth of 14.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:33 2025: Image # 5, module Resize # 10: CPU_time = 0.41 secs, Wall_time = 0.41 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:33 2025: Image # 5, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:33 2025: Image # 5, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:33 2025: Image # 5, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# [WARN] PixelType mismatch: OME=3, TIFF=1
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA1_PointA1_0002_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq0002.ome.tiff
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA1_PointA1_0002_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq0002.ome.tiff
# [WARN] PixelType mismatch: OME=3, TIFF=1
# [WARN] PixelType mismatch: OME=3, TIFF=1
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA1_PointA1_0002_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq0002.ome.tiff
# Reading IFDs
# Populating metadata
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:33 2025: Image # 6, module LoadData # 1: CPU_time = 0.57 secs, Wall_time = 0.45 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:33 2025: Image # 6, module Resize # 2: CPU_time = 0.03 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:33 2025: Image # 6, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (8883), equivalent to an approximate bitdepth of 13.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:33 2025: Image # 6, module Resize # 4: CPU_time = 0.15 secs, Wall_time = 0.15 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:34 2025: Image # 6, module Resize # 5: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:34 2025: Image # 6, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (5284), equivalent to an approximate bitdepth of 12.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:34 2025: Image # 6, module Resize # 7: CPU_time = 0.16 secs, Wall_time = 0.16 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:34 2025: Image # 6, module Resize # 8: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:34 2025: Image # 6, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (19269), equivalent to an approximate bitdepth of 14.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:34 2025: Image # 6, module Resize # 10: CPU_time = 0.40 secs, Wall_time = 0.40 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:34 2025: Image # 6, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:34 2025: Image # 6, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:34 2025: Image # 6, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# [WARN] PixelType mismatch: OME=3, TIFF=1
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA1_PointA1_0000_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq0000.ome.tiff
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA1_PointA1_0000_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq0000.ome.tiff
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA1_PointA1_0000_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq0000.ome.tiff
# Reading IFDs
# Populating metadata
# [WARN] PixelType mismatch: OME=3, TIFF=1
# [WARN] PixelType mismatch: OME=3, TIFF=1
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:34 2025: Image # 7, module LoadData # 1: CPU_time = 0.63 secs, Wall_time = 0.51 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:35 2025: Image # 7, module Resize # 2: CPU_time = 0.03 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:35 2025: Image # 7, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (8891), equivalent to an approximate bitdepth of 13.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:35 2025: Image # 7, module Resize # 4: CPU_time = 0.15 secs, Wall_time = 0.15 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:35 2025: Image # 7, module Resize # 5: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:35 2025: Image # 7, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (4619), equivalent to an approximate bitdepth of 12.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:35 2025: Image # 7, module Resize # 7: CPU_time = 0.16 secs, Wall_time = 0.16 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:35 2025: Image # 7, module Resize # 8: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:35 2025: Image # 7, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (18110), equivalent to an approximate bitdepth of 14.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:35 2025: Image # 7, module Resize # 10: CPU_time = 0.39 secs, Wall_time = 0.39 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:36 2025: Image # 7, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:36 2025: Image # 7, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:36 2025: Image # 7, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# [WARN] PixelType mismatch: OME=3, TIFF=1
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellB1_PointB1_0001_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq3076.ome.tiff
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellB1_PointB1_0001_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq3076.ome.tiff
# [WARN] PixelType mismatch: OME=3, TIFF=1
# [WARN] PixelType mismatch: OME=3, TIFF=1
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellB1_PointB1_0001_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq3076.ome.tiff
# Reading IFDs
# Populating metadata
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:36 2025: Image # 8, module LoadData # 1: CPU_time = 0.60 secs, Wall_time = 0.45 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:36 2025: Image # 8, module Resize # 2: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:36 2025: Image # 8, module CorrectIlluminationCalculate # 3: CPU_time = 0.01 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (7886), equivalent to an approximate bitdepth of 12.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:36 2025: Image # 8, module Resize # 4: CPU_time = 0.15 secs, Wall_time = 0.16 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:36 2025: Image # 8, module Resize # 5: CPU_time = 0.03 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:36 2025: Image # 8, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (4529), equivalent to an approximate bitdepth of 12.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:36 2025: Image # 8, module Resize # 7: CPU_time = 0.16 secs, Wall_time = 0.16 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:36 2025: Image # 8, module Resize # 8: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:36 2025: Image # 8, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (18184), equivalent to an approximate bitdepth of 14.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:36 2025: Image # 8, module Resize # 10: CPU_time = 0.40 secs, Wall_time = 0.40 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:37 2025: Image # 8, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:37 2025: Image # 8, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:37 2025: Image # 8, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# [WARN] PixelType mismatch: OME=3, TIFF=1
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA2_PointA2_0001_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq1026.ome.tiff
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA2_PointA2_0001_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq1026.ome.tiff
# [WARN] PixelType mismatch: OME=3, TIFF=1
# [WARN] PixelType mismatch: OME=3, TIFF=1
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA2_PointA2_0001_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq1026.ome.tiff
# Reading IFDs
# Populating metadata
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:37 2025: Image # 9, module LoadData # 1: CPU_time = 0.58 secs, Wall_time = 0.47 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:37 2025: Image # 9, module Resize # 2: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:37 2025: Image # 9, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (7284), equivalent to an approximate bitdepth of 12.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:37 2025: Image # 9, module Resize # 4: CPU_time = 0.17 secs, Wall_time = 0.16 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:37 2025: Image # 9, module Resize # 5: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:37 2025: Image # 9, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (4267), equivalent to an approximate bitdepth of 12.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:37 2025: Image # 9, module Resize # 7: CPU_time = 0.16 secs, Wall_time = 0.16 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:38 2025: Image # 9, module Resize # 8: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:38 2025: Image # 9, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (16393), equivalent to an approximate bitdepth of 14.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:38 2025: Image # 9, module Resize # 10: CPU_time = 0.39 secs, Wall_time = 0.39 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:38 2025: Image # 9, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:38 2025: Image # 9, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:38 2025: Image # 9, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# [WARN] PixelType mismatch: OME=3, TIFF=1
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA2_PointA2_0000_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq1025.ome.tiff
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA2_PointA2_0000_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq1025.ome.tiff
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA2_PointA2_0000_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq1025.ome.tiff
# Reading IFDs
# Populating metadata
# [WARN] PixelType mismatch: OME=3, TIFF=1
# [WARN] PixelType mismatch: OME=3, TIFF=1
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:38 2025: Image # 10, module LoadData # 1: CPU_time = 0.60 secs, Wall_time = 0.48 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:38 2025: Image # 10, module Resize # 2: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:39 2025: Image # 10, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (7058), equivalent to an approximate bitdepth of 12.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:39 2025: Image # 10, module Resize # 4: CPU_time = 0.15 secs, Wall_time = 0.15 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:39 2025: Image # 10, module Resize # 5: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:39 2025: Image # 10, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (4498), equivalent to an approximate bitdepth of 12.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:39 2025: Image # 10, module Resize # 7: CPU_time = 0.16 secs, Wall_time = 0.16 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:39 2025: Image # 10, module Resize # 8: CPU_time = 0.04 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:39 2025: Image # 10, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (16888), equivalent to an approximate bitdepth of 14.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:39 2025: Image # 10, module Resize # 10: CPU_time = 0.39 secs, Wall_time = 0.39 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:39 2025: Image # 10, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:39 2025: Image # 10, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:39 2025: Image # 10, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# [WARN] PixelType mismatch: OME=3, TIFF=1
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA2_PointA2_0002_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq1027.ome.tiff
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA2_PointA2_0002_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq1027.ome.tiff
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA2_PointA2_0002_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq1027.ome.tiff
# [WARN] PixelType mismatch: OME=3, TIFF=1
# [WARN] PixelType mismatch: OME=3, TIFF=1
# Reading IFDs
# Populating metadata
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:39 2025: Image # 11, module LoadData # 1: CPU_time = 0.73 secs, Wall_time = 0.60 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:40 2025: Image # 11, module Resize # 2: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:40 2025: Image # 11, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (6790), equivalent to an approximate bitdepth of 12.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:40 2025: Image # 11, module Resize # 4: CPU_time = 0.15 secs, Wall_time = 0.15 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:40 2025: Image # 11, module Resize # 5: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:40 2025: Image # 11, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (4760), equivalent to an approximate bitdepth of 12.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:40 2025: Image # 11, module Resize # 7: CPU_time = 0.16 secs, Wall_time = 0.16 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:40 2025: Image # 11, module Resize # 8: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:40 2025: Image # 11, module CorrectIlluminationCalculate # 9: CPU_time = 0.01 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (16484), equivalent to an approximate bitdepth of 14.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:40 2025: Image # 11, module Resize # 10: CPU_time = 0.38 secs, Wall_time = 0.39 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:41 2025: Image # 11, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:41 2025: Image # 11, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:41 2025: Image # 11, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# [WARN] PixelType mismatch: OME=3, TIFF=1
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA1_PointA1_0001_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq0001.ome.tiff
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA1_PointA1_0001_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq0001.ome.tiff
# [WARN] PixelType mismatch: OME=3, TIFF=1
# [WARN] PixelType mismatch: OME=3, TIFF=1
# Reading IFDs
# Populating metadata
# OMETiffReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/Batch1/images/Plate1/20X_CP_Plate1_20240319_122800_179/WellA1_PointA1_0001_ChannelPhalloAF750,ZO1-AF488,DAPI_Seq0001.ome.tiff
# Reading IFDs
# Populating metadata
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:41 2025: Image # 12, module LoadData # 1: CPU_time = 0.57 secs, Wall_time = 0.46 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:41 2025: Image # 12, module Resize # 2: CPU_time = 0.03 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:41 2025: Image # 12, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (6541), equivalent to an approximate bitdepth of 12.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:41 2025: Image # 12, module Resize # 4: CPU_time = 0.15 secs, Wall_time = 0.15 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:41 2025: Image # 12, module Resize # 5: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:41 2025: Image # 12, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (4463), equivalent to an approximate bitdepth of 12.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:41 2025: Image # 12, module Resize # 7: CPU_time = 0.15 secs, Wall_time = 0.15 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:41 2025: Image # 12, module Resize # 8: CPU_time = 0.03 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:41 2025: Image # 12, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (15728), equivalent to an approximate bitdepth of 13.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:41 2025: Image # 12, module Resize # 10: CPU_time = 0.38 secs, Wall_time = 0.38 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:42 2025: Image # 12, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:42 2025: Image # 12, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Sat Jun  7 09:24:42 2025: Image # 12, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# 100%|██████████| 1/1 [00:16<00:00, 16.56s/it]
# INFO:cellprofiler_core.utilities.java:Shutting down Java Virtual Machine
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_calc/Batch1-Plate1
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_calc/completed.txt.
# [Sat Jun  7 09:24:42 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:24:42 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_calc/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:24:42 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092420.415284.snakemake.log

# %% [markdown]
# ## Step 2: CP apply illum correction

# %% [markdown]
# ### Gen load data

# %%
cp_apply_illum_load_data_mod = CPApplyIllumGenLoadDataModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
cp_apply_illum_load_data_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    cp_apply_illum_load_data_mod.pipe,
    backend_config,
    exec_runs / "run006",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                            count
# ---------------------------  -------
# all                                1
# cp_apply_illum_gen_loaddata        1
# total                              2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:24:43 2025]
# localrule cp_apply_illum_gen_loaddata:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index/index.parquet
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/illum_apply/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight illum apply loaddata -i /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index/index.parquet -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/illum_apply --illum /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_calc --use_legacy --exp_config /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/experiment/experiment.json
# Could not load runstardist
# Could not load runomnipose
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/illum_apply/completed.txt.
# [Sat Jun  7 09:24:48 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:24:48 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/illum_apply/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:24:48 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092443.777746.snakemake.log

# %% [markdown]
# ### Gen cppipe file

# %%
cp_apply_illum_cppipe_mod = CPApplyIllumGenCPPipeModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
cp_apply_illum_cppipe_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    cp_apply_illum_cppipe_mod.pipe,
    backend_config,
    exec_runs / "run007",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                          count
# -------------------------  -------
# all                              1
# cp_apply_illum_gen_cppipe        1
# total                            2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:24:49 2025]
# localrule cp_apply_illum_gen_cppipe:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/illum_apply/completed.txt
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/illum_apply/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight illum apply cppipe -l /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/illum_apply -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/illum_apply -w /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply --nuclei DAPI --cell PhalloAF750 --use_legacy
# Could not load runstardist
# Could not load runomnipose
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/illum_apply/completed.txt.
# [Sat Jun  7 09:24:54 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:24:54 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/illum_apply/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:24:54 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092449.557049.snakemake.log

# %% [markdown]
# ### Invoke cppipe file

# %%
cp_apply_illum_invoke_mod = CPApplyIllumInvokeCPModule(
    data_config, pcp_experiment
)

exec_backend = SnakeMakeBackend(
    cp_apply_illum_invoke_mod.pipe,
    backend_config,
    exec_runs / "run008",
    exec_mounts,
)
run = exec_backend.run()
run.wait()

# ------------------------------------------------------------------
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                         count
# ------------------------  -------
# all                             1
# cp_apply_illum_invoke_cp        1
# total                           2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:24:55 2025]
# localrule cp_apply_illum_invoke_cp:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/illum_apply/completed.txt, /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/illum_apply/completed.txt, /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_calc/completed.txt
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight cp -p /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/illum_apply/illum_apply_painting.cppipe -l /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/illum_apply -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply
# Could not load runstardist
# Could not load runomnipose
# INFO:cellprofiler_core.utilities.java:Initializing Java Virtual Machine
#
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/Users/shsingh/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/Users/shsingh/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/Users/shsingh/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_3_CorrDNA.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_3_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_CorrDNA.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_2_CorrDNA.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_2_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_CorrDNA.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_2_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_CorrDNA.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_CorrDNA.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_CorrDNA.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_2_CorrDNA.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_2_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
#
#
# 100%|██████████| 1/1 [00:19<00:00, 19.80s/it]
#
# 100%|██████████| 1/1 [00:20<00:00, 20.57s/it]
# 100%|██████████| 1/1 [00:21<00:00, 21.89s/it]
# INFO:cellprofiler_core.utilities.java:Shutting down Java Virtual Machine
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A1
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-B1
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/completed.txt.
# [Sat Jun  7 09:25:25 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:25:25 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:25:25 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092455.342613.snakemake.log

# %% [markdown]
# ## Step 3: CP segcheck

# %% [markdown]
# ### Gen load data

# %%
cp_segcheck_load_data_mod = CPSegcheckGenLoadDataModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
cp_segcheck_load_data_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    cp_segcheck_load_data_mod.pipe,
    backend_config,
    exec_runs / "run009",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                        count
# -----------------------  -------
# all                            1
# cp_segchek_gen_loaddata        1
# total                          2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:25:26 2025]
# localrule cp_segchek_gen_loaddata:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index/index.parquet
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/segcheck/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight segcheck loaddata -i /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index/index.parquet -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/segcheck -c /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply --nuclei DAPI --cell PhalloAF750 --use_legacy --exp_config /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/experiment/experiment.json
# Could not load runstardist
# Could not load runomnipose
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/segcheck/completed.txt.
# [Sat Jun  7 09:25:32 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:25:32 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/segcheck/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:25:32 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092526.703164.snakemake.log

# %% [markdown]
# ### Gen cppipe file

# %%
cp_segcheck_cppipe_mod = CPSegcheckGenCPPipeModule(data_config, pcp_experiment)

# Change default value to use legacy pipeline compatible load data
cp_segcheck_cppipe_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    cp_segcheck_cppipe_mod.pipe,
    backend_config,
    exec_runs / "run010",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                       count
# ----------------------  -------
# all                           1
# cp_segcheck_gen_cppipe        1
# total                         2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:25:33 2025]
# localrule cp_segcheck_gen_cppipe:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/segcheck/completed.txt
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/segcheck/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight segcheck cppipe -l /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/segcheck -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/segcheck -w /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/segmentation/cp/segcheck -n DAPI -c PhalloAF750 --use_legacy
# Could not load runstardist
# Could not load runomnipose
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/segcheck/completed.txt.
# [Sat Jun  7 09:25:38 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:25:38 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/segcheck/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:25:38 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092533.660528.snakemake.log

# %% [markdown]
# ### Invoke cppipe file

# %%
cp_segcheck_invoke_mod = CPSegcheckInvokeCPModule(data_config, pcp_experiment)

exec_backend = SnakeMakeBackend(
    cp_segcheck_invoke_mod.pipe,
    backend_config,
    exec_runs / "run011",
    exec_mounts,
)
run = exec_backend.run()
run.wait()

# ------------------------------------------------------------------
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                      count
# ---------------------  -------
# all                          1
# cp_segcheck_invoke_cp        1
# total                        2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:25:39 2025]
# localrule cp_segcheck_invoke_cp:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/segcheck/completed.txt, /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/segcheck/completed.txt, /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/completed.txt
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/segmentation/cp/segcheck/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight cp -p /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/cp/segcheck/segcheck_painting.cppipe -l /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/cp/segcheck -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/segmentation/cp/segcheck
# Could not load runstardist
# Could not load runomnipose
# INFO:cellprofiler_core.utilities.java:Initializing Java Virtual Machine
#
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/Users/shsingh/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/Users/shsingh/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/Users/shsingh/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
#
# 100%|██████████| 1/1 [00:45<00:00, 45.24s/it]
# 100%|██████████| 1/1 [00:46<00:00, 46.31s/it]
#
#
# 100%|██████████| 1/1 [00:49<00:00, 49.66s/it]
# INFO:cellprofiler_core.utilities.java:Shutting down Java Virtual Machine
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/segmentation/cp/segcheck/Batch1-Plate1-A1
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/segmentation/cp/segcheck/Batch1-Plate1-A2
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/segmentation/cp/segcheck/Batch1-Plate1-B1
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/segmentation/cp/segcheck/completed.txt.
# [Sat Jun  7 09:26:37 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:26:37 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/segmentation/cp/segcheck/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:26:37 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092539.605561.snakemake.log

# %% [markdown]
# ## Step 5: SBS calculate illum correction

# %% [markdown]
# ### Gen load data

# %%
sbs_calc_illum_load_data_mod = SBSCalcIllumGenLoadDataModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
sbs_calc_illum_load_data_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    sbs_calc_illum_load_data_mod.pipe,
    backend_config,
    exec_runs / "run012",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                            count
# ---------------------------  -------
# all                                1
# sbs_calc_illum_gen_loaddata        1
# total                              2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:26:38 2025]
# localrule sbs_calc_illum_gen_loaddata:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index/index.parquet
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/illum_calc/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight illum calc loaddata -i /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index/index.parquet -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/illum_calc --sbs --use_legacy --exp_config /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/experiment/experiment.json
# Could not load runstardist
# Could not load runomnipose
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/illum_calc/completed.txt.
# [Sat Jun  7 09:26:45 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:26:45 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/illum_calc/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:26:45 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092638.687929.snakemake.log

# %% [markdown]
# ### Gen cppipe file

# %%
sbs_calc_illum_cppipe_mod = SBSCalcIllumGenCPPipeModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
sbs_calc_illum_cppipe_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    sbs_calc_illum_cppipe_mod.pipe,
    backend_config,
    exec_runs / "run013",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                          count
# -------------------------  -------
# all                              1
# sbs_calc_illum_gen_cppipe        1
# total                            2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:26:46 2025]
# localrule sbs_calc_illum_gen_cppipe:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/illum_calc/completed.txt
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/illum_calc/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight illum calc cppipe -l /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/illum_calc -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/illum_calc -w /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_calc --sbs --use_legacy
# Could not load runstardist
# Could not load runomnipose
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/illum_calc/completed.txt.
# [Sat Jun  7 09:26:51 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:26:51 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/illum_calc/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:26:51 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092645.988818.snakemake.log

# %% [markdown]
# ### Invoke cppipe file

# %%
sbs_calc_illum_invoke_mod = SBSCalcIllumInvokeCPModule(
    data_config, pcp_experiment
)

exec_backend = SnakeMakeBackend(
    sbs_calc_illum_invoke_mod.pipe,
    backend_config,
    exec_runs / "run014",
    exec_mounts,
)
run = exec_backend.run()
run.wait()

# ------------------------------------------------------------------
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                         count
# ------------------------  -------
# all                             1
# sbs_calc_illum_invoke_cp        1
# total                           2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:26:51 2025]
# localrule sbs_calc_illum_invoke_cp:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/illum_calc/completed.txt, /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/illum_calc/completed.txt
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_calc/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight cp -p /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/illum_calc/illum_calc_sbs.cppipe -l /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/illum_calc -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_calc --sbs
# Could not load runstardist
# Could not load runomnipose
# INFO:cellprofiler_core.utilities.java:Initializing Java Virtual Machine
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/Users/shsingh/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/Users/shsingh/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/Users/shsingh/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (53048), equivalent to an approximate bitdepth of 15.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (46374), equivalent to an approximate bitdepth of 15.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65270), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (29619), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65373), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65406), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65278), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65364), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65372), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (46984), equivalent to an approximate bitdepth of 15.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (61526), equivalent to an approximate bitdepth of 15.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (47186), equivalent to an approximate bitdepth of 15.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (37797), equivalent to an approximate bitdepth of 15.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (64649), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (27259), equivalent to an approximate bitdepth of 14.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (23121), equivalent to an approximate bitdepth of 14.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (38065), equivalent to an approximate bitdepth of 15.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65263), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (64221), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (23340), equivalent to an approximate bitdepth of 14.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (64679), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65276), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (64005), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (60726), equivalent to an approximate bitdepth of 15.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (30747), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (43192), equivalent to an approximate bitdepth of 15.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (29085), equivalent to an approximate bitdepth of 14.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (45132), equivalent to an approximate bitdepth of 15.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (36179), equivalent to an approximate bitdepth of 15.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (28266), equivalent to an approximate bitdepth of 14.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (15836), equivalent to an approximate bitdepth of 14.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (51852), equivalent to an approximate bitdepth of 15.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (25462), equivalent to an approximate bitdepth of 14.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (43853), equivalent to an approximate bitdepth of 15.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (17206), equivalent to an approximate bitdepth of 14.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (54610), equivalent to an approximate bitdepth of 15.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (58072), equivalent to an approximate bitdepth of 15.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (44089), equivalent to an approximate bitdepth of 15.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (24140), equivalent to an approximate bitdepth of 14.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (56990), equivalent to an approximate bitdepth of 15.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (25186), equivalent to an approximate bitdepth of 14.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (29460), equivalent to an approximate bitdepth of 14.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (27364), equivalent to an approximate bitdepth of 14.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (30425), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (14026), equivalent to an approximate bitdepth of 13.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (19874), equivalent to an approximate bitdepth of 14.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (47099), equivalent to an approximate bitdepth of 15.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (19161), equivalent to an approximate bitdepth of 14.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (33890), equivalent to an approximate bitdepth of 15.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (49686), equivalent to an approximate bitdepth of 15.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (15897), equivalent to an approximate bitdepth of 14.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (48677), equivalent to an approximate bitdepth of 15.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (34306), equivalent to an approximate bitdepth of 15.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (21521), equivalent to an approximate bitdepth of 14.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (46830), equivalent to an approximate bitdepth of 15.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (20194), equivalent to an approximate bitdepth of 14.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (22439), equivalent to an approximate bitdepth of 14.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (23319), equivalent to an approximate bitdepth of 14.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (22884), equivalent to an approximate bitdepth of 14.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (17071), equivalent to an approximate bitdepth of 14.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (12829), equivalent to an approximate bitdepth of 13.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (44266), equivalent to an approximate bitdepth of 15.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (15380), equivalent to an approximate bitdepth of 13.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (34034), equivalent to an approximate bitdepth of 15.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (12769), equivalent to an approximate bitdepth of 13.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (46745), equivalent to an approximate bitdepth of 15.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (43787), equivalent to an approximate bitdepth of 15.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (30783), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (19551), equivalent to an approximate bitdepth of 14.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (41612), equivalent to an approximate bitdepth of 15.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (18272), equivalent to an approximate bitdepth of 14.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (18384), equivalent to an approximate bitdepth of 14.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (19378), equivalent to an approximate bitdepth of 14.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (20330), equivalent to an approximate bitdepth of 14.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (14832), equivalent to an approximate bitdepth of 13.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (12808), equivalent to an approximate bitdepth of 13.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (37119), equivalent to an approximate bitdepth of 15.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (13678), equivalent to an approximate bitdepth of 13.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (11056), equivalent to an approximate bitdepth of 13.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (32883), equivalent to an approximate bitdepth of 15.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (39280), equivalent to an approximate bitdepth of 15.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (40139), equivalent to an approximate bitdepth of 15.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (30852), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (16914), equivalent to an approximate bitdepth of 14.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (39493), equivalent to an approximate bitdepth of 15.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (15663), equivalent to an approximate bitdepth of 13.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (16573), equivalent to an approximate bitdepth of 14.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (16614), equivalent to an approximate bitdepth of 14.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (17135), equivalent to an approximate bitdepth of 14.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (11034), equivalent to an approximate bitdepth of 13.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (12409), equivalent to an approximate bitdepth of 13.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (34864), equivalent to an approximate bitdepth of 15.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (11761), equivalent to an approximate bitdepth of 13.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (10853), equivalent to an approximate bitdepth of 13.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (31588), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (37635), equivalent to an approximate bitdepth of 15.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (37230), equivalent to an approximate bitdepth of 15.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (28325), equivalent to an approximate bitdepth of 14.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (14750), equivalent to an approximate bitdepth of 13.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (36537), equivalent to an approximate bitdepth of 15.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (13518), equivalent to an approximate bitdepth of 13.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (18606), equivalent to an approximate bitdepth of 14.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (14834), equivalent to an approximate bitdepth of 13.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (18583), equivalent to an approximate bitdepth of 14.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (10673), equivalent to an approximate bitdepth of 13.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (10596), equivalent to an approximate bitdepth of 13.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (32704), equivalent to an approximate bitdepth of 15.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (10776), equivalent to an approximate bitdepth of 13.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (34808), equivalent to an approximate bitdepth of 15.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (10288), equivalent to an approximate bitdepth of 13.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (28370), equivalent to an approximate bitdepth of 14.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (35157), equivalent to an approximate bitdepth of 15.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (27859), equivalent to an approximate bitdepth of 14.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (13073), equivalent to an approximate bitdepth of 13.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (34964), equivalent to an approximate bitdepth of 15.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (11866), equivalent to an approximate bitdepth of 13.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (16703), equivalent to an approximate bitdepth of 14.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (13291), equivalent to an approximate bitdepth of 13.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (16511), equivalent to an approximate bitdepth of 14.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (10505), equivalent to an approximate bitdepth of 13.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (9518), equivalent to an approximate bitdepth of 13.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (33241), equivalent to an approximate bitdepth of 15.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (9608), equivalent to an approximate bitdepth of 13.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (27409), equivalent to an approximate bitdepth of 14.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (34858), equivalent to an approximate bitdepth of 15.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (9175), equivalent to an approximate bitdepth of 13.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (32881), equivalent to an approximate bitdepth of 15.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (25618), equivalent to an approximate bitdepth of 14.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (13102), equivalent to an approximate bitdepth of 13.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (32878), equivalent to an approximate bitdepth of 15.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (11834), equivalent to an approximate bitdepth of 13.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (15167), equivalent to an approximate bitdepth of 13.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (15155), equivalent to an approximate bitdepth of 13.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (12721), equivalent to an approximate bitdepth of 13.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (9480), equivalent to an approximate bitdepth of 13.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (9036), equivalent to an approximate bitdepth of 13.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (31563), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (9453), equivalent to an approximate bitdepth of 13.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (25888), equivalent to an approximate bitdepth of 14.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (32627), equivalent to an approximate bitdepth of 15.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (8283), equivalent to an approximate bitdepth of 13.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (24901), equivalent to an approximate bitdepth of 14.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (34802), equivalent to an approximate bitdepth of 15.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (12626), equivalent to an approximate bitdepth of 13.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (14087), equivalent to an approximate bitdepth of 13.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (35051), equivalent to an approximate bitdepth of 15.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (11315), equivalent to an approximate bitdepth of 13.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (13994), equivalent to an approximate bitdepth of 13.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (11703), equivalent to an approximate bitdepth of 13.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (9194), equivalent to an approximate bitdepth of 13.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (8288), equivalent to an approximate bitdepth of 13.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (30945), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (9440), equivalent to an approximate bitdepth of 13.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (25884), equivalent to an approximate bitdepth of 14.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (32251), equivalent to an approximate bitdepth of 15.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (8018), equivalent to an approximate bitdepth of 13.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (25322), equivalent to an approximate bitdepth of 14.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (32756), equivalent to an approximate bitdepth of 15.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (12353), equivalent to an approximate bitdepth of 13.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (13736), equivalent to an approximate bitdepth of 13.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (33321), equivalent to an approximate bitdepth of 15.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (11062), equivalent to an approximate bitdepth of 13.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (13649), equivalent to an approximate bitdepth of 13.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (11365), equivalent to an approximate bitdepth of 13.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (7973), equivalent to an approximate bitdepth of 13.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (8449), equivalent to an approximate bitdepth of 13.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (9098), equivalent to an approximate bitdepth of 13.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (30432), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (25725), equivalent to an approximate bitdepth of 14.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (8234), equivalent to an approximate bitdepth of 13.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (31507), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (24787), equivalent to an approximate bitdepth of 14.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (31341), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (13502), equivalent to an approximate bitdepth of 13.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (11419), equivalent to an approximate bitdepth of 13.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (32218), equivalent to an approximate bitdepth of 15.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (13287), equivalent to an approximate bitdepth of 13.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (10159), equivalent to an approximate bitdepth of 13.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# 100%|██████████| 1/1 [00:39<00:00, 39.31s/it]
#
#
# 100%|██████████| 1/1 [00:39<00:00, 39.34s/it]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (12098), equivalent to an approximate bitdepth of 13.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (8441), equivalent to an approximate bitdepth of 13.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
#
# 100%|██████████| 1/1 [00:40<00:00, 40.24s/it]
# INFO:cellprofiler_core.utilities.java:Shutting down Java Virtual Machine
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_calc/Batch1-Plate1-3
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_calc/Batch1-Plate1-1
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_calc/Batch1-Plate1-2
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_calc/completed.txt.
# [Sat Jun  7 09:27:41 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:27:41 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_calc/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:27:41 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092651.942443.snakemake.log

# %% [markdown]
# ## Step 6: SBS apply illum correction

# %% [markdown]
# ### Gen load data

# %%
sbs_apply_illum_load_data_mod = SBSApplyIllumGenLoadDataModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
sbs_apply_illum_load_data_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    sbs_apply_illum_load_data_mod.pipe,
    backend_config,
    exec_runs / "run015",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                             count
# ----------------------------  -------
# all                                 1
# sbs_apply_illum_gen_loaddata        1
# total                               2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:27:42 2025]
# localrule sbs_apply_illum_gen_loaddata:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index/index.parquet
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/illum_apply/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight illum apply loaddata -i /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index/index.parquet -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/illum_apply --nuclei DAPI --sbs --use_legacy --exp_config /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/experiment/experiment.json
# Could not load runstardist
# Could not load runomnipose
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/illum_apply/completed.txt.
# [Sat Jun  7 09:27:48 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:27:48 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/illum_apply/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:27:48 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092742.478462.snakemake.log

# %% [markdown]
# ### Gen cppipe file

# %%
sbs_apply_illum_cppipe_mod = SBSApplyIllumGenCPPipeModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
sbs_apply_illum_cppipe_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    sbs_apply_illum_cppipe_mod.pipe,
    backend_config,
    exec_runs / "run016",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                           count
# --------------------------  -------
# all                               1
# sbs_apply_illum_gen_cppipe        1
# total                             2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:27:49 2025]
# localrule sbs_apply_illum_gen_cppipe:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/illum_apply/completed.txt
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/illum_apply/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight illum apply cppipe -l /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/illum_apply -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/illum_apply -w /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply --nuclei DAPI --sbs --use_legacy
# Could not load runstardist
# Could not load runomnipose
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/illum_apply/completed.txt.
# [Sat Jun  7 09:27:54 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:27:54 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/illum_apply/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:27:54 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092749.381054.snakemake.log

# %% [markdown]
# ### Invoke cppipe file

# %%
sbs_apply_illum_invoke_mod = SBSApplyIllumInvokeCPModule(
    data_config, pcp_experiment
)

exec_backend = SnakeMakeBackend(
    sbs_apply_illum_invoke_mod.pipe,
    backend_config,
    exec_runs / "run017",
    exec_mounts,
)
run = exec_backend.run()
run.wait()

# ------------------------------------------------------------------
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                          count
# -------------------------  -------
# all                              1
# sbs_apply_illum_invoke_cp        1
# total                            2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:27:55 2025]
# localrule sbs_apply_illum_invoke_cp:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/illum_apply/completed.txt, /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/illum_apply/completed.txt, /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_calc/completed.txt
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight cp -p /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/illum_apply/illum_apply_sbs.cppipe -l /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/illum_apply -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply --sbs
# Could not load runstardist
# Could not load runomnipose
# INFO:cellprofiler_core.utilities.java:Initializing Java Virtual Machine
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]Experiment-wide values for mean threshold, etc calculated by MeasureImageQuality may be incorrect if the run is split into subsets of images.
# Experiment-wide values for mean threshold, etc calculated by MeasureImageQuality may be incorrect if the run is split into subsets of images.
# Experiment-wide values for mean threshold, etc calculated by MeasureImageQuality may be incorrect if the run is split into subsets of images.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/Users/shsingh/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/Users/shsingh/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/Users/shsingh/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: divide by zero encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: invalid value encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: divide by zero encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: invalid value encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: divide by zero encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: invalid value encountered in divide
#   corrnorm = corr12 / sd
# 100%|██████████| 1/1 [00:42<00:00, 42.76s/it]
#
# 100%|██████████| 1/1 [00:44<00:00, 44.09s/it]
#
#
# 100%|██████████| 1/1 [00:45<00:00, 45.84s/it]
# INFO:cellprofiler_core.utilities.java:Shutting down Java Virtual Machine
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/completed.txt.
# [Sat Jun  7 09:28:50 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:28:50 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:28:50 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092755.490496.snakemake.log

# %% [markdown]
# ## Step 7: SBS preprocess

# %% [markdown]
# ### Gen load data

# %%
sbs_preprocess_load_data_mod = SBSPreprocessGenLoadDataModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
sbs_preprocess_load_data_mod.spec.inputs["use_legacy"].value = True
# Fix align path for legacy module
sbs_preprocess_load_data_mod.spec.inputs[
    "aligned_images_path"
].value = sbs_preprocess_load_data_mod.spec.inputs[
    "corrected_images_path"
].value
exec_backend = SnakeMakeBackend(
    sbs_preprocess_load_data_mod.pipe,
    backend_config,
    exec_runs / "run018",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                            count
# ---------------------------  -------
# all                                1
# sbs_preprocess_gen_loaddata        1
# total                              2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:29:19 2025]
# localrule sbs_preprocess_gen_loaddata:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index/index.parquet
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/preprocess/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight preprocess loaddata -i /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index/index.parquet -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/preprocess -c /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply -a /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply -n DAPI --use_legacy --exp_config /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/experiment/experiment.json
# Could not load runstardist
# Could not load runomnipose
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/preprocess/completed.txt.
# [Sat Jun  7 09:29:25 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:29:25 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/preprocess/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:29:25 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092919.543458.snakemake.log

# %% [markdown]
# ### Gen cppipe file

# %%
sbs_preprocess_cppipe_mod = SBSPreprocessGenCPPipeModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
sbs_preprocess_cppipe_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    sbs_preprocess_cppipe_mod.pipe,
    backend_config,
    exec_runs / "run019",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                          count
# -------------------------  -------
# all                              1
# sbs_preprocess_gen_cppipe        1
# total                            2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:29:35 2025]
# localrule sbs_preprocess_gen_cppipe:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/preprocess/completed.txt
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/preprocess/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight preprocess cppipe -l /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/preprocess -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/preprocess -w /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs -b /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv -n DAPI --use_legacy
# Could not load runstardist
# Could not load runomnipose
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/preprocess/completed.txt.
# [Sat Jun  7 09:29:40 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:29:40 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/preprocess/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:29:40 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T092935.608962.snakemake.log

# %% [markdown]
# ### Invoke cppipe file

# %%
sbs_preprocess_invoke_mod = SBSPreprocessInvokeCPModule(
    data_config, pcp_experiment
)
# Add the CP plugin directory
sbs_preprocess_invoke_mod.spec.inputs["plugin_path"].value = (
    "../../../scratch/CellProfiler-plugins/active_plugins/"
)

exec_backend = SnakeMakeBackend(
    sbs_preprocess_invoke_mod.pipe,
    backend_config,
    exec_runs / "run020",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# ------------------------------------------------------------------
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                         count
# ------------------------  -------
# all                             1
# sbs_preprocess_invoke_cp        1
# total                           2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:30:45 2025]
# localrule sbs_preprocess_invoke_cp:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/preprocess/completed.txt, /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/preprocess/completed.txt, /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/completed.txt
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight cp -p /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/sbs/preprocess/preprocess_sbs.cppipe -l /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/sbs/preprocess -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs --sbs --plugin_dir ../../../scratch/CellProfiler-plugins/active_plugins/
# Could not load runstardist
# Could not load runomnipose
# INFO:cellprofiler_core.utilities.java:Initializing Java Virtual Machine
#
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]Could not load runstardist
# Could not load runstardist
# Could not load runstardist
# Could not load runomnipose
# Could not load runomnipose
# Could not load runomnipose
# [ERROR] "loci.formats.in.WlzReader" is not valid.
# [ERROR] "loci.formats.in.IonpathMIBITiffReader" is not valid.
# [ERROR] "loci.formats.in.WlzReader" is not valid.
# [ERROR] "loci.formats.in.WlzReader" is not valid.
# [ERROR] "loci.formats.in.IonpathMIBITiffReader" is not valid.
# [ERROR] "loci.formats.in.IonpathMIBITiffReader" is not valid.
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle03_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle03_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle02_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle02_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:441: RuntimeWarning: invalid value encountered in divide
#   cmi_x[lindexes - 1] = i_x / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:442: RuntimeWarning: invalid value encountered in divide
#   cmi_y[lindexes - 1] = i_y / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:443: RuntimeWarning: invalid value encountered in divide
#   cmi_z[lindexes - 1] = i_z / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:441: RuntimeWarning: invalid value encountered in divide
#   cmi_x[lindexes - 1] = i_x / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:442: RuntimeWarning: invalid value encountered in divide
#   cmi_y[lindexes - 1] = i_y / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:443: RuntimeWarning: invalid value encountered in divide
#   cmi_z[lindexes - 1] = i_z / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:441: RuntimeWarning: invalid value encountered in divide
#   cmi_x[lindexes - 1] = i_x / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:442: RuntimeWarning: invalid value encountered in divide
#   cmi_y[lindexes - 1] = i_y / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:443: RuntimeWarning: invalid value encountered in divide
#   cmi_z[lindexes - 1] = i_z / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle01_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle01_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle01_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle01_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle02_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle02_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle02_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle02_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle03_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle03_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle03_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle03_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle03_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle01_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle01_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle01_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle01_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle02_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle02_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle02_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle02_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle03_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle03_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle03_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle03_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle03_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle02_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle02_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_2_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_2_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_2_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_2_Cycle03_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# ...
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_3_Cycle01_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_3_Cycle01_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_3_Cycle01_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_3_Cycle02_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_3_Cycle02_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_3_Cycle02_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_3_Cycle02_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_3_Cycle03_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_3_Cycle03_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_3_Cycle03_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_3_Cycle03_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# 100%|██████████| 1/1 [01:03<00:00, 63.25s/it]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle01_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle01_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle01_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle01_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle02_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle02_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle02_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle02_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle03_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle03_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle03_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle03_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle01_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle01_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle01_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle01_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle02_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle02_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle02_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle02_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle03_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle03_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle03_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle03_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
#
#
# 100%|██████████| 1/1 [01:09<00:00, 69.43s/it]
#
# 100%|██████████| 1/1 [01:09<00:00, 69.71s/it]
# INFO:cellprofiler_core.utilities.java:Shutting down Java Virtual Machine
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/completed.txt.
# [Sat Jun  7 09:32:04 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:32:04 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:32:04 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T093045.856451.snakemake.log

# %% [markdown]
# ## Step 9: Analysis

# %% [markdown]
# ### Gen load data

# %%
analysis_load_data_mod = AnalysisGenLoadDataModule(data_config, pcp_experiment)

# Change default value to use legacy pipeline compatible load data
analysis_load_data_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    analysis_load_data_mod.pipe,
    backend_config,
    exec_runs / "run021",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                      count
# ---------------------  -------
# all                          1
# analysis_gen_loaddata        1
# total                        2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:32:42 2025]
# localrule analysis_gen_loaddata:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index/index.parquet
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/analysis/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight analysis loaddata -i /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/index/index.parquet -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/analysis --corr_images /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply --comp_images /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs --use_legacy --exp_config /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/experiment/experiment.json
# Could not load runstardist
# Could not load runomnipose
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/analysis/completed.txt.
# [Sat Jun  7 09:32:48 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:32:48 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/analysis/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:32:48 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T093242.548629.snakemake.log

# %% [markdown]
# ### Gen cppipe file

# %%
analysis_cppipe_mod = AnalysisGenCPPipeModule(data_config, pcp_experiment)

# Change default value to use legacy pipeline compatible load data
analysis_cppipe_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    analysis_cppipe_mod.pipe,
    backend_config,
    exec_runs / "run022",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                    count
# -------------------  -------
# all                        1
# analysis_gen_cppipe        1
# total                      2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:34:20 2025]
# localrule analysis_gen_cppipe:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/analysis/completed.txt
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/analysis/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight analysis cppipe -l /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/analysis -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/analysis -w /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis -b /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv -n DAPI -e PhalloAF750 -m ZO1AF488 --use_legacy
# Could not load runstardist
# Could not load runomnipose
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/analysis/completed.txt.
# [Sat Jun  7 09:34:25 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:34:25 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/analysis/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:34:25 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T093420.246857.snakemake.log

# %% [markdown]
# ### Invoke cppipe file

# %%
analysis_invoke_mod = AnalysisInvokeCPModule(data_config, pcp_experiment)

# Add the CP plugin directory
analysis_invoke_mod.spec.inputs["plugin_path"].value = (
    "../../../scratch/CellProfiler-plugins/active_plugins/"
)

exec_backend = SnakeMakeBackend(
    analysis_invoke_mod.pipe,
    backend_config,
    exec_runs / "run023",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wm89a-c9c
# Building DAG of jobs...
# Using shell: /nix/store/qzwsj5ihx6kjwikr0g77dnhcfxm1by68-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                   count
# ------------------  -------
# all                       1
# analysis_invoke_cp        1
# total                     2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:34:32 2025]
# localrule analysis_invoke_cp:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/analysis/completed.txt, /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/analysis/completed.txt, /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/completed.txt, /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/segmentation/cp/segcheck/completed.txt
#     output: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# starrynight cp -p /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/cppipe/analysis/analysis.cppipe -l /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/cellprofiler/loaddata/analysis -o /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis --plugin_dir ../../../scratch/CellProfiler-plugins/active_plugins/
# Could not load runstardist
# Could not load runomnipose
# INFO:cellprofiler_core.utilities.java:Initializing Java Virtual Machine
#
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]Could not load runstardist
# Could not load runstardist
# Could not load runstardist
# Could not load runomnipose
# Could not load runomnipose
# Could not load runomnipose
# Morph's 'Life' option has been removed, this pipeline might not be compatible with the current version of CellProfiler.
# Morph's 'Life' option has been removed, this pipeline might not be compatible with the current version of CellProfiler.
# Morph's 'Life' option has been removed, this pipeline might not be compatible with the current version of CellProfiler.
# Experiment-wide values for mean threshold, etc calculated by MeasureImageQuality may be incorrect if the run is split into subsets of images.
# Experiment-wide values for mean threshold, etc calculated by MeasureImageQuality may be incorrect if the run is split into subsets of images.
# Experiment-wide values for mean threshold, etc calculated by MeasureImageQuality may be incorrect if the run is split into subsets of images.
# [ERROR] "loci.formats.in.WlzReader" is not valid.
# [ERROR] "loci.formats.in.IonpathMIBITiffReader" is not valid.
# [ERROR] "loci.formats.in.WlzReader" is not valid.
# [ERROR] "loci.formats.in.WlzReader" is not valid.
# [ERROR] "loci.formats.in.IonpathMIBITiffReader" is not valid.
# [ERROR] "loci.formats.in.IonpathMIBITiffReader" is not valid.
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_CorrPhalloidin.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_CorrPhalloidin.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_CorrPhalloidin.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_CorrDNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_CorrZO1.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_CorrDNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_0_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_CorrZO1.tiff
# Reading IFDs
# Populating metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_CorrDNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_CorrZO1.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_0_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: divide by zero encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: invalid value encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: divide by zero encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: invalid value encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: divide by zero encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:441: RuntimeWarning: invalid value encountered in divide
#   cmi_x[lindexes - 1] = i_x / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:442: RuntimeWarning: invalid value encountered in divide
#   cmi_y[lindexes - 1] = i_y / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:443: RuntimeWarning: invalid value encountered in divide
#   cmi_z[lindexes - 1] = i_z / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:441: RuntimeWarning: invalid value encountered in divide
#   cmi_x[lindexes - 1] = i_x / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:442: RuntimeWarning: invalid value encountered in divide
#   cmi_y[lindexes - 1] = i_y / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:443: RuntimeWarning: invalid value encountered in divide
#   cmi_z[lindexes - 1] = i_z / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:441: RuntimeWarning: invalid value encountered in divide
#   cmi_x[lindexes - 1] = i_x / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:442: RuntimeWarning: invalid value encountered in divide
#   cmi_y[lindexes - 1] = i_y / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:443: RuntimeWarning: invalid value encountered in divide
#   cmi_z[lindexes - 1] = i_z / integrated_intensity[lindexes - 1]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:982: RuntimeWarning: invalid value encountered in divide
#   scipy.ndimage.sum(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:991: RuntimeWarning: invalid value encountered in divide
#   (
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:1002: RuntimeWarning: invalid value encountered in divide
#   scipy.ndimage.sum(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:377: RuntimeWarning: invalid value encountered in divide
#   integrated_intensity[lindexes - 1] / lcount
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/scipy/ndimage/_measurements.py:805: RuntimeWarning: invalid value encountered in divide
#   return sum / np.asanyarray(count).astype(np.float64)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:520: RuntimeWarning: invalid value encountered in divide
#   integrated_intensity_edge[lindexes - 1] / ecount
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:982: RuntimeWarning: invalid value encountered in divide
#   scipy.ndimage.sum(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:991: RuntimeWarning: invalid value encountered in divide
#   (
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:1002: RuntimeWarning: invalid value encountered in divide
#   scipy.ndimage.sum(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:982: RuntimeWarning: invalid value encountered in divide
#   scipy.ndimage.sum(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:991: RuntimeWarning: invalid value encountered in divide
#   (
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:1002: RuntimeWarning: invalid value encountered in divide
#   scipy.ndimage.sum(
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:377: RuntimeWarning: invalid value encountered in divide
#   integrated_intensity[lindexes - 1] / lcount
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/scipy/ndimage/_measurements.py:805: RuntimeWarning: invalid value encountered in divide
#   return sum / np.asanyarray(count).astype(np.float64)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:520: RuntimeWarning: invalid value encountered in divide
#   integrated_intensity_edge[lindexes - 1] / ecount
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:377: RuntimeWarning: invalid value encountered in divide
#   integrated_intensity[lindexes - 1] / lcount
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/scipy/ndimage/_measurements.py:805: RuntimeWarning: invalid value encountered in divide
#   return sum / np.asanyarray(count).astype(np.float64)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:520: RuntimeWarning: invalid value encountered in divide
#   integrated_intensity_edge[lindexes - 1] / ecount
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_CorrDNA_SpotOverlay.png is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/util/dtype.py:527: UserWarning: Downcasting int32 to uint16 without scaling because max value 1093 fits in uint16
#   return _convert(image, np.uint16, force_copy)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A1/segmentation_masks/Plate_Plate1_Well_A1_Site_0_Cells_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A1/segmentation_masks/Plate_Plate1_Well_A1_Site_0_Cytoplasm_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A1/segmentation_masks/Plate_Plate1_Well_A1_Site_0_Nuclei_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_CorrPhalloidin.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_CorrDNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_CorrZO1.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/util/dtype.py:527: UserWarning: Downcasting int32 to uint16 without scaling because max value 1047 fits in uint16
#   return _convert(image, np.uint16, force_copy)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A2/segmentation_masks/Plate_Plate1_Well_A2_Site_0_Cells_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A2/segmentation_masks/Plate_Plate1_Well_A2_Site_0_Cytoplasm_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A2/segmentation_masks/Plate_Plate1_Well_A2_Site_0_Nuclei_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_CorrPhalloidin.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_CorrDNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_CorrZO1.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/util/dtype.py:527: UserWarning: Downcasting int32 to uint16 without scaling because max value 1679 fits in uint16
#   return _convert(image, np.uint16, force_copy)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-B1/segmentation_masks/Plate_Plate1_Well_B1_Site_0_Cells_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-B1/segmentation_masks/Plate_Plate1_Well_B1_Site_0_Cytoplasm_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-B1/segmentation_masks/Plate_Plate1_Well_B1_Site_0_Nuclei_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_CorrPhalloidin.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: invalid value encountered in divide
#   corrnorm = corr12 / sd
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_CorrDNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_CorrZO1.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_1_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/util/dtype.py:527: UserWarning: Downcasting int32 to uint16 without scaling because max value 1118 fits in uint16
#   return _convert(image, np.uint16, force_copy)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A1/segmentation_masks/Plate_Plate1_Well_A1_Site_1_Cells_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A1/segmentation_masks/Plate_Plate1_Well_A1_Site_1_Cytoplasm_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A1/segmentation_masks/Plate_Plate1_Well_A1_Site_1_Nuclei_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_2_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_2_CorrPhalloidin.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_2_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_2_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_2_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_2_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_2_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_2_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_2_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# ...
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_CorrDNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_CorrZO1.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_3_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/util/dtype.py:527: UserWarning: Downcasting int32 to uint16 without scaling because max value 1295 fits in uint16
#   return _convert(image, np.uint16, force_copy)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-B1/segmentation_masks/Plate_Plate1_Well_B1_Site_2_Cells_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-B1/segmentation_masks/Plate_Plate1_Well_B1_Site_2_Cytoplasm_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-B1/segmentation_masks/Plate_Plate1_Well_B1_Site_2_Nuclei_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_CorrPhalloidin.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_CorrDNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_CorrZO1.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/util/dtype.py:527: UserWarning: Downcasting int32 to uint16 without scaling because max value 994 fits in uint16
#   return _convert(image, np.uint16, force_copy)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A1/segmentation_masks/Plate_Plate1_Well_A1_Site_3_Cells_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A1/segmentation_masks/Plate_Plate1_Well_A1_Site_3_Cytoplasm_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A1/segmentation_masks/Plate_Plate1_Well_A1_Site_3_Nuclei_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
#
# 100%|██████████| 1/1 [03:35<00:00, 215.02s/it]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/util/dtype.py:527: UserWarning: Downcasting int32 to uint16 without scaling because max value 997 fits in uint16
#   return _convert(image, np.uint16, force_copy)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A2/segmentation_masks/Plate_Plate1_Well_A2_Site_3_Cells_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A2/segmentation_masks/Plate_Plate1_Well_A2_Site_3_Cytoplasm_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A2/segmentation_masks/Plate_Plate1_Well_A2_Site_3_Nuclei_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
#
#
# 100%|██████████| 1/1 [03:46<00:00, 226.61s/it]
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/skimage/util/dtype.py:527: UserWarning: Downcasting int32 to uint16 without scaling because max value 1688 fits in uint16
#   return _convert(image, np.uint16, force_copy)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-B1/segmentation_masks/Plate_Plate1_Well_B1_Site_3_Cells_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-B1/segmentation_masks/Plate_Plate1_Well_B1_Site_3_Cytoplasm_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/sz4fipcrqs5qzbss97r33wgy0c1mzppz-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-B1/segmentation_masks/Plate_Plate1_Well_B1_Site_3_Nuclei_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# 100%|██████████| 1/1 [03:56<00:00, 236.03s/it]
# INFO:cellprofiler_core.utilities.java:Shutting down Java Virtual Machine
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A1
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-A2
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/Batch1-Plate1-B1
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# self.csv_path: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_input/Source1/workspace/metadata/Barcodes.csv
# Touching output file /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/completed.txt.
# [Sat Jun  7 09:38:37 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sat Jun  7 09:38:37 2025]
# localrule all:
#     input: /Users/shsingh/Documents/GitHub/starrynight/scratch/fix_s1_output/workspace/analysis/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp/nix-shell.tc4gjV
#
# echo 'done' > completed.txt
# [Sat Jun  7 09:38:37 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-06-07T093432.496099.snakemake.log

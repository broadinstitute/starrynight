# %% [markdown]
# # Execute PCP generic pipeline step by step

# %% [markdown]
# ## Imports

# %%
from pathlib import Path

from pipecraft.backend.snakemake import SnakeMakeBackend, SnakeMakeConfig

from starrynight.experiments.common import AcquisitionOrderType, ImageFrameType
from starrynight.experiments.pcp_generic import PCPGeneric, PCPGenericInitConfig
from starrynight.modules.analysis.analysis_cp import AnalysisInvokeCPModule
from starrynight.modules.analysis.analysis_cppipe import AnalysisGenCPPipeModule
from starrynight.modules.analysis.analysis_load_data import (
    AnalysisGenLoadDataModule,
)
from starrynight.modules.cp_illum_apply.apply_cp import (
    CPApplyIllumInvokeCPModule,
)
from starrynight.modules.cp_illum_apply.apply_cppipe import (
    CPApplyIllumGenCPPipeModule,
)
from starrynight.modules.cp_illum_apply.apply_load_data import (
    CPApplyIllumGenLoadDataModule,
)

# cp_illum_calc
from starrynight.modules.cp_illum_calc.calc_cp import CPCalcIllumInvokeCPModule
from starrynight.modules.cp_illum_calc.calc_cppipe import (
    CPCalcIllumGenCPPipeModule,
)
from starrynight.modules.cp_illum_calc.calc_load_data import (
    CPCalcIllumGenLoadDataModule,
)

# cp_segcheck
from starrynight.modules.cp_segcheck.segcheck_cp import CPSegcheckInvokeCPModule
from starrynight.modules.cp_segcheck.segcheck_cppipe import (
    CPSegcheckGenCPPipeModule,
)
from starrynight.modules.cp_segcheck.segcheck_load_data import (
    CPSegcheckGenLoadDataModule,
)

# inventory and index
from starrynight.modules.gen_index import GenIndexModule
from starrynight.modules.gen_inv import GenInvModule
from starrynight.modules.sbs_illum_apply.apply_cp import (
    SBSApplyIllumInvokeCPModule,
)
from starrynight.modules.sbs_illum_apply.apply_cppipe import (
    SBSApplyIllumGenCPPipeModule,
)
from starrynight.modules.sbs_illum_apply.apply_load_data import (
    SBSApplyIllumGenLoadDataModule,
)
from starrynight.modules.sbs_illum_calc.calc_cp import (
    SBSCalcIllumInvokeCPModule,
)
from starrynight.modules.sbs_illum_calc.calc_cppipe import (
    SBSCalcIllumGenCPPipeModule,
)
from starrynight.modules.sbs_illum_calc.calc_load_data import (
    SBSCalcIllumGenLoadDataModule,
)
from starrynight.modules.sbs_preprocess.preprocess_cp import (
    SBSPreprocessInvokeCPModule,
)  # noqa: E501
from starrynight.modules.sbs_preprocess.preprocess_cppipe import (
    SBSPreprocessGenCPPipeModule,
)
from starrynight.modules.sbs_preprocess.preprocess_load_data import (
    SBSPreprocessGenLoadDataModule,
)
from starrynight.schema import DataConfig

# %% [markdown]
# ## Setup dataset paths
# These paths are required for creating the `DataConfig` object and configure the execution backend.

# %%
dataset_path = Path("../../../scratch/starrynight_example_input")
barcode_csv_path = dataset_path.joinpath("workspace/metadata/barcode.csv")
workspace_path = Path("../../../scratch/new_starrynight_example_output")
exec_runs = Path("../../../scratch/new_starrynight_runs")
exec_mounts = Path("../../../scratch/new_starrynight_mounts")

# %% [markdown]
# ## Create data config

# %%
data_config = DataConfig(
    dataset_path=dataset_path,
    storage_path=dataset_path,
    workspace_path=workspace_path,
)

# %% [markdown]
# ## Create execution engine config config
# Here we are creating a `SnakeMakeBackend` config.
# We can also use other backends like `NextflowBackend` and `AWSBatchBackend`

# %%
backend_config = SnakeMakeConfig(
    use_fluent_bit=False, print_exec=True, background=False
)

# %% [markdown]
# ## Configure the generate inventory module
# This module is special and doesn't require an experiment for configuration

# %%
gen_inv_mod = GenInvModule(data_config)
exec_backend = SnakeMakeBackend(
    gen_inv_mod.pipe, backend_config, exec_runs / "run001", exec_mounts
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                   count
# ------------------  -------
# all                       1
# generate_inventory        1
# total                     2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 10:41:15 2025]
# localrule generate_inventory:
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/inventory/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight inventory gen -d /home/ank/workspace/hub/broad/starrynight/scratch/starrynight_example_input -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/inventory
#
#
#
#
#
#
#
#
#
#
#
#
#
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 5753.50it/s][A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Writing inventory:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 5841.65it/s]
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 6721.64it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 5398.07it/s][A
#
#
#
#
#
#
#
#
#
#
#
#
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 5645.09it/s][A
#
#
#
#
#
#
#
#
#
#
#
#
#
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 26051.58it/s]A
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 4013.69it/s]
#
#
#
#
#
#
#
#
#
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 5737.76it/s][A
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 11848.32it/s]
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 3452.10it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 6472.69it/s][A
#
#
#
#
#
#
#
#
#
#
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 23563.51it/s]A
#
#
#
#
#
#
#
#
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 20164.92it/s]A
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 5614.86it/s]
#
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 5809.29it/s]
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 25266.89it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 6232.25it/s][A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Writing inventory:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# Writing inventory:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 5857.97it/s]
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 25266.89it/s]A
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 5974.79it/s]
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 26715.31it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 20164.92it/s]A[A
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 5777.28it/s]
#
#
#
#
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 26214.40it/s]A
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 24818.37it/s]
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 6105.25it/s]
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 5882.61it/s]
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 5540.69it/s]
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 6413.31it/s]
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 5793.24it/s]
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 6150.01it/s]
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 5614.86it/s]
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 5825.42it/s]
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 5577.53it/s]
# Writing inventory: 100%|██████████| 1/1 [00:00<00:00, 6009.03it/s]
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/inventory/completed.txt.
# [Thu May 15 10:41:19 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 10:41:19 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/inventory/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 10:41:19 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T104115.726383.snakemake.log
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 7
#       5 run = exec_backend.run()
#       6 run.wait()
# ----> 7 run.print_log()
#
# File ~/workspace/hub/broad/starrynight/pipecraft/src/pipecraft/backend/base.py:57, in BaseBackendRun.print_log(self)
#      55 def print_log(self) -> None:
#      56     """Print run log."""
# ---> 57     with self.log_path.open() as f:
#      58         pprint(f.readlines())
#
# File /nix/store/nmqxyr00in2arwrq5qd1qipsanz1yrn5-python3-3.11.10/lib/python3.11/pathlib.py:1044, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1042 if "b" not in mode:
#    1043     encoding = io.text_encoding(encoding)
# -> 1044 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../scratch/new_starrynight_runs/run001/nohup.out'

# %% [markdown]
# ## Configure the generate index module
# This module is special and doesn't require an experiment for configuration

# %%
gen_ind_mod = GenIndexModule(data_config)
exec_backend = SnakeMakeBackend(
    gen_ind_mod.pipe, backend_config, exec_runs / "run002", exec_mounts
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job               count
# --------------  -------
# all                   1
# generate_index        1
# total                 2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 10:43:45 2025]
# localrule generate_index:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/inventory/inventory.parquet
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index/index.parquet
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight index gen -i /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/inventory/inventory.parquet -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index
# Generating Index: 1it [00:00, 92.02it/s]
# Unable to parse: {'key': 'starrynight_example_input/workspace/metadata/barcode.csv', 'filename': 'barcode.csv', 'extension': '.csv', 'prefix': '/home/ank/workspace/hub/broad/starrynight/scratch'} because of Unexpected token Token('WORKSPACE', 'workspace') at line 1, column 27.
# Expected one of:
# 	* LETTER
# 	* DIGIT
# [Thu May 15 10:43:48 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 10:43:48 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index/index.parquet
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 10:43:48 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T104345.742246.snakemake.log

# %% [markdown]
# ## Configure the experiment with the generated index

# %%
index_path = workspace_path / "index/index.parquet"
pcp_exp_init = PCPGenericInitConfig(
    barcode_csv_path=barcode_csv_path.resolve(),
    cp_acquisition_order=AcquisitionOrderType.SNAKE,
    cp_img_frame_type=ImageFrameType.ROUND,
    cp_img_overlap_pct=10,
    sbs_acquisition_order=AcquisitionOrderType.SNAKE,
    sbs_img_frame_type=ImageFrameType.ROUND,
    sbs_img_overlap_pct=10,
    cp_nuclei_channel="DAPI",
    cp_cell_channel="PhalloAF750",
    cp_mito_channel="ZO1AF488",
    sbs_nuclei_channel="DAPI",
    sbs_cell_channel="PhalloAF750",
    sbs_mito_channel="ZO1AF488",
)
pcp_experiment = PCPGeneric.from_index(index_path, pcp_exp_init.model_dump())

# %%
# Write out the experiment as a json file
experiment_dir = data_config.workspace_path.joinpath("experiment")
experiment_dir.mkdir(parents=True, exist_ok=True)
experiment_dir.joinpath("experiment.json").write_text(
    pcp_experiment.model_dump_json()
)
# Out:
# 878

# %% [markdown]
# ## Configure the following modules with the experiment
#
# ------------------------------------------------------------------

# %% [markdown]
# ## Step 1: CP calculate illum correction

# %% [markdown]
# ### Gen load data

# %%
cp_calc_illum_load_data_mod = CPCalcIllumGenLoadDataModule(
    data_config, pcp_experiment
)
# Change default value to use legacy pipeline compatible load data
cp_calc_illum_load_data_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    cp_calc_illum_load_data_mod.pipe,
    backend_config,
    exec_runs / "run003",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                           count
# --------------------------  -------
# all                               1
# cp_calc_illum_gen_loaddata        1
# total                             2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 10:48:15 2025]
# localrule cp_calc_illum_gen_loaddata:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index/index.parquet
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/illum_calc/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight illum calc loaddata -i /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index/index.parquet -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/illum_calc --use_legacy --exp_config /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/experiment/experiment.json
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/illum_calc/completed.txt.
# [Thu May 15 10:48:18 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 10:48:18 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/illum_calc/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 10:48:18 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T104815.674359.snakemake.log

# %% [markdown]
# ### Gen cppipe file

# %%
cp_calc_illum_cppipe_mod = CPCalcIllumGenCPPipeModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
cp_calc_illum_cppipe_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    cp_calc_illum_cppipe_mod.pipe,
    backend_config,
    exec_runs / "run004",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                      count
# ---------------------  -------
# all                          1
# calc_illum_gen_cppipe        1
# total                        2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 10:50:01 2025]
# localrule calc_illum_gen_cppipe:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/illum_calc/completed.txt
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/illum_calc/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight illum calc cppipe -l /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/illum_calc -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/illum_calc -w /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_calc --use_legacy
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/illum_calc/completed.txt.
# [Thu May 15 10:50:03 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 10:50:03 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/illum_calc/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 10:50:03 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T105001.173086.snakemake.log

# %% [markdown]
# ### Invoke cppipe file

# %%
cp_calc_illum_invoke_mod = CPCalcIllumInvokeCPModule(
    data_config, pcp_experiment
)

exec_backend = SnakeMakeBackend(
    cp_calc_illum_invoke_mod.pipe,
    backend_config,
    exec_runs / "run005",
    exec_mounts,
)
run = exec_backend.run()
run.wait()

# ------------------------------------------------------------------
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                        count
# -----------------------  -------
# all                            1
# cp_calc_illum_invoke_cp        1
# total                          2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 10:50:54 2025]
# localrule cp_calc_illum_invoke_cp:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/illum_calc/completed.txt, /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/illum_calc/illum_calc_painting.cppipe
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_calc/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight cp -p /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/illum_calc/illum_calc_painting.cppipe -l /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/illum_calc -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_calc
# INFO:cellprofiler_core.utilities.java:Initializing Java Virtual Machine
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
#   0%|          | 0/1 [00:00<?, ?it/s]INFO:cellprofiler_core.pipeline._pipeline:Times reported are CPU and Wall-clock times for each module
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:57 2025: Image # 1, module LoadData # 1: CPU_time = 1.69 secs, Wall_time = 0.83 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:57 2025: Image # 1, module Resize # 2: CPU_time = 0.13 secs, Wall_time = 0.11 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:58 2025: Image # 1, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (28486), equivalent to an approximate bitdepth of 14.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:58 2025: Image # 1, module Resize # 4: CPU_time = 0.18 secs, Wall_time = 0.18 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:58 2025: Image # 1, module Resize # 5: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:58 2025: Image # 1, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (13748), equivalent to an approximate bitdepth of 13.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:58 2025: Image # 1, module Resize # 7: CPU_time = 0.23 secs, Wall_time = 0.23 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:58 2025: Image # 1, module Resize # 8: CPU_time = 0.03 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:58 2025: Image # 1, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (55742), equivalent to an approximate bitdepth of 15.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:58 2025: Image # 1, module Resize # 10: CPU_time = 0.65 secs, Wall_time = 0.66 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:59 2025: Image # 1, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:59 2025: Image # 1, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:59 2025: Image # 1, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:59 2025: Image # 2, module LoadData # 1: CPU_time = 0.60 secs, Wall_time = 0.43 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:59 2025: Image # 2, module Resize # 2: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:59 2025: Image # 2, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (17778), equivalent to an approximate bitdepth of 14.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:59 2025: Image # 2, module Resize # 4: CPU_time = 0.17 secs, Wall_time = 0.17 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:59 2025: Image # 2, module Resize # 5: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:59 2025: Image # 2, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (8569), equivalent to an approximate bitdepth of 13.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:50:59 2025: Image # 2, module Resize # 7: CPU_time = 0.22 secs, Wall_time = 0.23 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:00 2025: Image # 2, module Resize # 8: CPU_time = 0.03 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:00 2025: Image # 2, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (29682), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:00 2025: Image # 2, module Resize # 10: CPU_time = 0.56 secs, Wall_time = 0.56 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:00 2025: Image # 2, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:00 2025: Image # 2, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:00 2025: Image # 2, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:00 2025: Image # 3, module LoadData # 1: CPU_time = 0.56 secs, Wall_time = 0.43 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:01 2025: Image # 3, module Resize # 2: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:01 2025: Image # 3, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (13067), equivalent to an approximate bitdepth of 13.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:01 2025: Image # 3, module Resize # 4: CPU_time = 0.19 secs, Wall_time = 0.19 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:01 2025: Image # 3, module Resize # 5: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:01 2025: Image # 3, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (7424), equivalent to an approximate bitdepth of 12.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:01 2025: Image # 3, module Resize # 7: CPU_time = 0.23 secs, Wall_time = 0.23 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:01 2025: Image # 3, module Resize # 8: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:01 2025: Image # 3, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (29776), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:01 2025: Image # 3, module Resize # 10: CPU_time = 0.61 secs, Wall_time = 0.60 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:02 2025: Image # 3, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:02 2025: Image # 3, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:02 2025: Image # 3, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:02 2025: Image # 4, module LoadData # 1: CPU_time = 0.49 secs, Wall_time = 0.42 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:02 2025: Image # 4, module Resize # 2: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:02 2025: Image # 4, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (9865), equivalent to an approximate bitdepth of 13.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:02 2025: Image # 4, module Resize # 4: CPU_time = 0.18 secs, Wall_time = 0.18 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:02 2025: Image # 4, module Resize # 5: CPU_time = 0.03 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:02 2025: Image # 4, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (6102), equivalent to an approximate bitdepth of 12.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:02 2025: Image # 4, module Resize # 7: CPU_time = 0.19 secs, Wall_time = 0.20 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:03 2025: Image # 4, module Resize # 8: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:03 2025: Image # 4, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (25628), equivalent to an approximate bitdepth of 14.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:03 2025: Image # 4, module Resize # 10: CPU_time = 0.56 secs, Wall_time = 0.56 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:03 2025: Image # 4, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:03 2025: Image # 4, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:03 2025: Image # 4, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:03 2025: Image # 5, module LoadData # 1: CPU_time = 0.49 secs, Wall_time = 0.42 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:04 2025: Image # 5, module Resize # 2: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:04 2025: Image # 5, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (9214), equivalent to an approximate bitdepth of 13.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:04 2025: Image # 5, module Resize # 4: CPU_time = 0.17 secs, Wall_time = 0.17 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:04 2025: Image # 5, module Resize # 5: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:04 2025: Image # 5, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (5244), equivalent to an approximate bitdepth of 12.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:04 2025: Image # 5, module Resize # 7: CPU_time = 0.19 secs, Wall_time = 0.19 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:04 2025: Image # 5, module Resize # 8: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:04 2025: Image # 5, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (21053), equivalent to an approximate bitdepth of 14.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:04 2025: Image # 5, module Resize # 10: CPU_time = 0.53 secs, Wall_time = 0.53 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:05 2025: Image # 5, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:05 2025: Image # 5, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:05 2025: Image # 5, module SaveImages # 14: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:05 2025: Image # 6, module LoadData # 1: CPU_time = 0.82 secs, Wall_time = 0.58 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:05 2025: Image # 6, module Resize # 2: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:05 2025: Image # 6, module CorrectIlluminationCalculate # 3: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (8208), equivalent to an approximate bitdepth of 13.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:05 2025: Image # 6, module Resize # 4: CPU_time = 0.17 secs, Wall_time = 0.17 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:05 2025: Image # 6, module Resize # 5: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:05 2025: Image # 6, module CorrectIlluminationCalculate # 6: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (5539), equivalent to an approximate bitdepth of 12.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:05 2025: Image # 6, module Resize # 7: CPU_time = 0.19 secs, Wall_time = 0.19 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:06 2025: Image # 6, module Resize # 8: CPU_time = 0.02 secs, Wall_time = 0.02 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:06 2025: Image # 6, module CorrectIlluminationCalculate # 9: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (21406), equivalent to an approximate bitdepth of 14.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:06 2025: Image # 6, module Resize # 10: CPU_time = 0.53 secs, Wall_time = 0.52 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:06 2025: Image # 6, module SaveImages # 11: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:06 2025: Image # 6, module SaveImages # 12: CPU_time = 0.00 secs, Wall_time = 0.00 secs
# INFO:cellprofiler_core.pipeline._pipeline:Thu May 15 10:51:06 2025: Image # 6, module SaveImages # 14: CPU_time = 0.01 secs, Wall_time = 0.00 secs
# 100%|██████████| 1/1 [00:09<00:00,  9.54s/it]
# INFO:cellprofiler_core.utilities.java:Shutting down Java Virtual Machine
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_calc/Batch1-Plate1
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_calc/completed.txt.
# [Thu May 15 10:51:07 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 10:51:07 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_calc/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 10:51:07 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T105054.678738.snakemake.log

# %% [markdown]
# ## Step 2: CP apply illum correction

# %% [markdown]
# ### Gen load data

# %%
cp_apply_illum_load_data_mod = CPApplyIllumGenLoadDataModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
cp_apply_illum_load_data_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    cp_apply_illum_load_data_mod.pipe,
    backend_config,
    exec_runs / "run006",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                            count
# ---------------------------  -------
# all                                1
# cp_apply_illum_gen_loaddata        1
# total                              2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 11:04:35 2025]
# localrule cp_apply_illum_gen_loaddata:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index/index.parquet
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/illum_apply/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight illum apply loaddata -i /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index/index.parquet -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/illum_apply --illum /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_calc --use_legacy --exp_config /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/experiment/experiment.json
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/illum_apply/completed.txt.
# [Thu May 15 11:04:37 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 11:04:37 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/illum_apply/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 11:04:37 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T110435.004604.snakemake.log

# %% [markdown]
# ### Gen cppipe file

# %%
cp_apply_illum_cppipe_mod = CPApplyIllumGenCPPipeModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
cp_apply_illum_cppipe_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    cp_apply_illum_cppipe_mod.pipe,
    backend_config,
    exec_runs / "run007",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                          count
# -------------------------  -------
# all                              1
# cp_apply_illum_gen_cppipe        1
# total                            2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 10:52:08 2025]
# localrule cp_apply_illum_gen_cppipe:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/illum_apply/completed.txt
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/illum_apply/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight illum apply cppipe -l /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/illum_apply -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/illum_apply -w /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply --nuclei DAPI --cell PhalloAF750 --use_legacy
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/illum_apply/completed.txt.
# [Thu May 15 10:52:10 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 10:52:10 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/illum_apply/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 10:52:10 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T105208.220402.snakemake.log

# %% [markdown]
# ### Invoke cppipe file

# %%
cp_apply_illum_invoke_mod = CPApplyIllumInvokeCPModule(
    data_config, pcp_experiment
)

exec_backend = SnakeMakeBackend(
    cp_apply_illum_invoke_mod.pipe,
    backend_config,
    exec_runs / "run008",
    exec_mounts,
)
run = exec_backend.run()
run.wait()

# ------------------------------------------------------------------
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                         count
# ------------------------  -------
# all                             1
# cp_apply_illum_invoke_cp        1
# total                           2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 11:04:44 2025]
# localrule cp_apply_illum_invoke_cp:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/illum_apply/completed.txt, /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/illum_apply/completed.txt, /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_calc/completed.txt
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight cp -p /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/illum_apply/illum_apply_painting.cppipe -l /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/illum_apply -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply
# INFO:cellprofiler_core.utilities.java:Initializing Java Virtual Machine
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_CorrDNA.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_CorrDNA.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_CorrDNA.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_CorrDNA.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_CorrDNA.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_CorrDNA.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_CorrPhalloidin.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
#
# 100%|██████████| 1/1 [00:09<00:00,  9.88s/it]
# 100%|██████████| 1/1 [00:10<00:00, 10.39s/it]
#
#
# 100%|██████████| 1/1 [00:10<00:00, 10.49s/it]
# INFO:cellprofiler_core.utilities.java:Shutting down Java Virtual Machine
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A1
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A2
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-B1
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/completed.txt.
# [Thu May 15 11:04:59 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 11:04:59 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 11:04:59 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T110444.939814.snakemake.log

# %% [markdown]
# ## Step 3: CP segcheck

# %% [markdown]
# ### Gen load data

# %%
cp_segcheck_load_data_mod = CPSegcheckGenLoadDataModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
cp_segcheck_load_data_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    cp_segcheck_load_data_mod.pipe,
    backend_config,
    exec_runs / "run009",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                        count
# -----------------------  -------
# all                            1
# cp_segchek_gen_loaddata        1
# total                          2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 11:46:30 2025]
# localrule cp_segchek_gen_loaddata:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index/index.parquet
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/segcheck/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight segcheck loaddata -i /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index/index.parquet -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/segcheck -c /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply --nuclei DAPI --cell PhalloAF750 --use_legacy --exp_config /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/experiment/experiment.json
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/segcheck/completed.txt.
# [Thu May 15 11:46:33 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 11:46:33 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/segcheck/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 11:46:33 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T114630.768263.snakemake.log

# %% [markdown]
# ### Gen cppipe file

# %%
cp_segcheck_cppipe_mod = CPSegcheckGenCPPipeModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
cp_segcheck_cppipe_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    cp_segcheck_cppipe_mod.pipe,
    backend_config,
    exec_runs / "run010",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                       count
# ----------------------  -------
# all                           1
# cp_segcheck_gen_cppipe        1
# total                         2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 11:40:31 2025]
# localrule cp_segcheck_gen_cppipe:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/segcheck/completed.txt
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/segcheck/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight segcheck cppipe -l /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/segcheck -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/segcheck -w /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/segmentation/cp/segcheck -n DAPI -c PhalloAF750 --use_legacy
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/segcheck/completed.txt.
# [Thu May 15 11:40:33 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 11:40:33 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/segcheck/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 11:40:33 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T114031.334553.snakemake.log

# %% [markdown]
# ### Invoke cppipe file

# %%
cp_segcheck_invoke_mod = CPSegcheckInvokeCPModule(
    data_config, pcp_experiment
)

exec_backend = SnakeMakeBackend(
    cp_segcheck_invoke_mod.pipe,
    backend_config,
    exec_runs / "run011",
    exec_mounts,
)
run = exec_backend.run()
run.wait()

# ------------------------------------------------------------------
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                      count
# ---------------------  -------
# all                          1
# cp_segcheck_invoke_cp        1
# total                        2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 11:46:40 2025]
# localrule cp_segcheck_invoke_cp:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/segcheck/completed.txt, /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/segcheck/completed.txt, /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/completed.txt
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/segmentation/cp/segcheck/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight cp -p /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/cp/segcheck/segcheck_painting.cppipe -l /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/cp/segcheck -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/segmentation/cp/segcheck
# INFO:cellprofiler_core.utilities.java:Initializing Java Virtual Machine
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# 100%|██████████| 1/1 [00:24<00:00, 24.07s/it]
#
#
# 100%|██████████| 1/1 [00:25<00:00, 25.96s/it]
#
# 100%|██████████| 1/1 [00:26<00:00, 26.06s/it]
# INFO:cellprofiler_core.utilities.java:Shutting down Java Virtual Machine
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/segmentation/cp/segcheck/Batch1-Plate1-A1
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/segmentation/cp/segcheck/Batch1-Plate1-B1
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/segmentation/cp/segcheck/Batch1-Plate1-A2
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/segmentation/cp/segcheck/completed.txt.
# [Thu May 15 11:47:09 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 11:47:09 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/segmentation/cp/segcheck/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 11:47:09 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T114640.031482.snakemake.log

# %% [markdown]
# ## Step 5: SBS calculate illum correction

# %% [markdown]
# ### Gen load data

# %%
sbs_calc_illum_load_data_mod = SBSCalcIllumGenLoadDataModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
sbs_calc_illum_load_data_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    sbs_calc_illum_load_data_mod.pipe,
    backend_config,
    exec_runs / "run012",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                            count
# ---------------------------  -------
# all                                1
# sbs_calc_illum_gen_loaddata        1
# total                              2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 12:32:49 2025]
# localrule sbs_calc_illum_gen_loaddata:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index/index.parquet
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/illum_calc/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight illum calc loaddata -i /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index/index.parquet -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/illum_calc --sbs --use_legacy --exp_config /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/experiment/experiment.json
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/illum_calc/completed.txt.
# [Thu May 15 12:32:51 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 12:32:51 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/illum_calc/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 12:32:51 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T123249.162619.snakemake.log

# %% [markdown]
# ### Gen cppipe file

# %%
sbs_calc_illum_cppipe_mod = SBSCalcIllumGenCPPipeModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
sbs_calc_illum_cppipe_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    sbs_calc_illum_cppipe_mod.pipe,
    backend_config,
    exec_runs / "run013",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                          count
# -------------------------  -------
# all                              1
# sbs_calc_illum_gen_cppipe        1
# total                            2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 12:35:59 2025]
# localrule sbs_calc_illum_gen_cppipe:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/illum_calc/completed.txt
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/illum_calc/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight illum calc cppipe -l /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/illum_calc -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/illum_calc -w /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_calc --sbs --use_legacy
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/illum_calc/completed.txt.
# [Thu May 15 12:36:01 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 12:36:01 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/illum_calc/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 12:36:01 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T123559.424561.snakemake.log

# %% [markdown]
# ### Invoke cppipe file

# %%
sbs_calc_illum_invoke_mod = SBSCalcIllumInvokeCPModule(
    data_config, pcp_experiment
)

exec_backend = SnakeMakeBackend(
    sbs_calc_illum_invoke_mod.pipe,
    backend_config,
    exec_runs / "run014",
    exec_mounts,
)
run = exec_backend.run()
run.wait()

# ------------------------------------------------------------------
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                         count
# ------------------------  -------
# all                             1
# sbs_calc_illum_invoke_cp        1
# total                           2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 12:38:47 2025]
# localrule sbs_calc_illum_invoke_cp:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/illum_calc/completed.txt, /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/illum_calc/completed.txt
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_calc/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight cp -p /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/illum_calc/illum_calc_sbs.cppipe -l /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/illum_calc -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_calc --sbs
# INFO:cellprofiler_core.utilities.java:Initializing Java Virtual Machine
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (39716), equivalent to an approximate bitdepth of 15.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (32704), equivalent to an approximate bitdepth of 15.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (38429), equivalent to an approximate bitdepth of 15.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65358), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65408), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65328), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65304), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65395), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65372), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (51602), equivalent to an approximate bitdepth of 15.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65103), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (34684), equivalent to an approximate bitdepth of 15.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (17353), equivalent to an approximate bitdepth of 14.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (34223), equivalent to an approximate bitdepth of 15.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (51012), equivalent to an approximate bitdepth of 15.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (33296), equivalent to an approximate bitdepth of 15.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (26268), equivalent to an approximate bitdepth of 14.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (51026), equivalent to an approximate bitdepth of 15.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (21502), equivalent to an approximate bitdepth of 14.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (20460), equivalent to an approximate bitdepth of 14.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (31333), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (53884), equivalent to an approximate bitdepth of 15.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (65167), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (35794), equivalent to an approximate bitdepth of 15.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (17773), equivalent to an approximate bitdepth of 14.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (54681), equivalent to an approximate bitdepth of 15.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (40812), equivalent to an approximate bitdepth of 15.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (64987), equivalent to an approximate bitdepth of 16.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (39667), equivalent to an approximate bitdepth of 15.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (19465), equivalent to an approximate bitdepth of 14.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (33763), equivalent to an approximate bitdepth of 15.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (19028), equivalent to an approximate bitdepth of 14.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (26576), equivalent to an approximate bitdepth of 14.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (22086), equivalent to an approximate bitdepth of 14.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (15948), equivalent to an approximate bitdepth of 14.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (24962), equivalent to an approximate bitdepth of 14.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (49141), equivalent to an approximate bitdepth of 15.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (17852), equivalent to an approximate bitdepth of 14.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (54602), equivalent to an approximate bitdepth of 15.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (14726), equivalent to an approximate bitdepth of 13.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (48522), equivalent to an approximate bitdepth of 15.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (34446), equivalent to an approximate bitdepth of 15.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (53476), equivalent to an approximate bitdepth of 15.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (22834), equivalent to an approximate bitdepth of 14.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (34744), equivalent to an approximate bitdepth of 15.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (21610), equivalent to an approximate bitdepth of 14.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (25902), equivalent to an approximate bitdepth of 14.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (23085), equivalent to an approximate bitdepth of 14.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (19621), equivalent to an approximate bitdepth of 14.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (14473), equivalent to an approximate bitdepth of 13.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (22593), equivalent to an approximate bitdepth of 14.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (39858), equivalent to an approximate bitdepth of 15.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (15503), equivalent to an approximate bitdepth of 13.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (11832), equivalent to an approximate bitdepth of 13.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (41839), equivalent to an approximate bitdepth of 15.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (47832), equivalent to an approximate bitdepth of 15.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (29904), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (30345), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (44851), equivalent to an approximate bitdepth of 15.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (20489), equivalent to an approximate bitdepth of 14.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (19309), equivalent to an approximate bitdepth of 14.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (18987), equivalent to an approximate bitdepth of 14.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (18324), equivalent to an approximate bitdepth of 14.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (21604), equivalent to an approximate bitdepth of 14.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (12452), equivalent to an approximate bitdepth of 13.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (38763), equivalent to an approximate bitdepth of 15.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (16141), equivalent to an approximate bitdepth of 14.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (11558), equivalent to an approximate bitdepth of 13.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (12454), equivalent to an approximate bitdepth of 13.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (30071), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (36448), equivalent to an approximate bitdepth of 15.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (38881), equivalent to an approximate bitdepth of 15.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (31099), equivalent to an approximate bitdepth of 14.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (16776), equivalent to an approximate bitdepth of 14.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (39630), equivalent to an approximate bitdepth of 15.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (15590), equivalent to an approximate bitdepth of 13.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (16458), equivalent to an approximate bitdepth of 14.0.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (18478), equivalent to an approximate bitdepth of 14.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (17847), equivalent to an approximate bitdepth of 14.1.
#   image, footprint, out, mask, n_bins = _preprocess_input(
#
# 100%|██████████| 1/1 [00:18<00:00, 18.32s/it]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (12086), equivalent to an approximate bitdepth of 13.6.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (13177), equivalent to an approximate bitdepth of 13.7.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (36571), equivalent to an approximate bitdepth of 15.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (11292), equivalent to an approximate bitdepth of 13.5.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (36470), equivalent to an approximate bitdepth of 15.2.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (39653), equivalent to an approximate bitdepth of 15.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (39277), equivalent to an approximate bitdepth of 15.3.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (15186), equivalent to an approximate bitdepth of 13.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (14051), equivalent to an approximate bitdepth of 13.8.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# 100%|██████████| 1/1 [00:21<00:00, 21.16s/it]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (15248), equivalent to an approximate bitdepth of 13.9.
#   image, footprint, out, mask, n_bins = _preprocess_input(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/filters/rank/generic.py:332: UserWarning: Bad rank filter performance is expected due to a large number of bins (11155), equivalent to an approximate bitdepth of 13.4.
#   image, footprint, out, mask, n_bins = _preprocess_input(
#
#
# 100%|██████████| 1/1 [00:21<00:00, 21.94s/it]
# INFO:cellprofiler_core.utilities.java:Shutting down Java Virtual Machine
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_calc/Batch1-Plate1-1
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_calc/Batch1-Plate1-3
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_calc/Batch1-Plate1-2
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_calc/completed.txt.
# [Thu May 15 12:39:13 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 12:39:13 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_calc/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 12:39:13 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T123847.979181.snakemake.log

# %% [markdown]
# ## Step 6: SBS apply illum correction

# %% [markdown]
# ### Gen load data

# %%
sbs_apply_illum_load_data_mod = SBSApplyIllumGenLoadDataModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
sbs_apply_illum_load_data_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    sbs_apply_illum_load_data_mod.pipe,
    backend_config,
    exec_runs / "run015",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                             count
# ----------------------------  -------
# all                                 1
# sbs_apply_illum_gen_loaddata        1
# total                               2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 12:52:27 2025]
# localrule sbs_apply_illum_gen_loaddata:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index/index.parquet
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/illum_apply/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight illum apply loaddata -i /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index/index.parquet -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/illum_apply --nuclei DAPI --sbs --use_legacy --exp_config /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/experiment/experiment.json
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/illum_apply/completed.txt.
# [Thu May 15 12:52:30 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 12:52:30 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/illum_apply/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 12:52:30 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T125227.948989.snakemake.log

# %% [markdown]
# ### Gen cppipe file

# %%
sbs_apply_illum_cppipe_mod = SBSApplyIllumGenCPPipeModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
sbs_apply_illum_cppipe_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    sbs_apply_illum_cppipe_mod.pipe,
    backend_config,
    exec_runs / "run016",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                           count
# --------------------------  -------
# all                               1
# sbs_apply_illum_gen_cppipe        1
# total                             2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 12:42:41 2025]
# localrule sbs_apply_illum_gen_cppipe:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/illum_apply/completed.txt
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/illum_apply/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight illum apply cppipe -l /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/illum_apply -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/illum_apply -w /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply --nuclei DAPI --sbs --use_legacy
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/illum_apply/completed.txt.
# [Thu May 15 12:42:43 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 12:42:43 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/illum_apply/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 12:42:43 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T124241.275414.snakemake.log

# %% [markdown]
# ### Invoke cppipe file

# %%
sbs_apply_illum_invoke_mod = SBSApplyIllumInvokeCPModule(
    data_config, pcp_experiment
)

exec_backend = SnakeMakeBackend(
    sbs_apply_illum_invoke_mod.pipe,
    backend_config,
    exec_runs / "run017",
    exec_mounts,
)
run = exec_backend.run()
run.wait()

# ------------------------------------------------------------------
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                          count
# -------------------------  -------
# all                              1
# sbs_apply_illum_invoke_cp        1
# total                            2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 12:52:39 2025]
# localrule sbs_apply_illum_invoke_cp:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/illum_apply/completed.txt, /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/illum_apply/completed.txt, /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_calc/completed.txt
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight cp -p /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/illum_apply/illum_apply_sbs.cppipe -l /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/illum_apply -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply --sbs
# INFO:cellprofiler_core.utilities.java:Initializing Java Virtual Machine
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]Experiment-wide values for mean threshold, etc calculated by MeasureImageQuality may be incorrect if the run is split into subsets of images.
# Experiment-wide values for mean threshold, etc calculated by MeasureImageQuality may be incorrect if the run is split into subsets of images.
# Experiment-wide values for mean threshold, etc calculated by MeasureImageQuality may be incorrect if the run is split into subsets of images.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: divide by zero encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: invalid value encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: divide by zero encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: invalid value encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: divide by zero encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: invalid value encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_DAPI.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle02_DAPI.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle03_DAPI.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle03_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle03_DAPI.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_DAPI.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_DAPI.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_DAPI.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle02_DAPI.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle03_DAPI.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
#
# 100%|██████████| 1/1 [00:22<00:00, 22.52s/it]
# 100%|██████████| 1/1 [00:22<00:00, 22.76s/it]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_DAPI.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
#
#
# 100%|██████████| 1/1 [00:23<00:00, 23.43s/it]
# INFO:cellprofiler_core.utilities.java:Shutting down Java Virtual Machine
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/completed.txt.
# [Thu May 15 12:53:07 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 12:53:07 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 12:53:07 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T125239.857644.snakemake.log

# %% [markdown]
# ## Step 7: SBS preprocess

# %% [markdown]
# ### Gen load data

# %%
sbs_preprocess_load_data_mod = SBSPreprocessGenLoadDataModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
sbs_preprocess_load_data_mod.spec.inputs["use_legacy"].value = True
#Fix align path for legacy module
sbs_preprocess_load_data_mod.spec.inputs["aligned_images_path"].value = sbs_preprocess_load_data_mod.spec.inputs["corrected_images_path"].value
exec_backend = SnakeMakeBackend(
    sbs_preprocess_load_data_mod.pipe,
    backend_config,
    exec_runs / "run018",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                            count
# ---------------------------  -------
# all                                1
# sbs_preprocess_gen_loaddata        1
# total                              2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 14:14:52 2025]
# localrule sbs_preprocess_gen_loaddata:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index/index.parquet
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/preprocess/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight preprocess loaddata -i /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index/index.parquet -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/preprocess -c /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply -a /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply -n DAPI --use_legacy --exp_config /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/experiment/experiment.json
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/preprocess/completed.txt.
# [Thu May 15 14:14:55 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 14:14:55 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/preprocess/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 14:14:55 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T141452.503534.snakemake.log

# %% [markdown]
# ### Gen cppipe file

# %%
sbs_preprocess_cppipe_mod = SBSPreprocessGenCPPipeModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
sbs_preprocess_cppipe_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    sbs_preprocess_cppipe_mod.pipe,
    backend_config,
    exec_runs / "run019",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                          count
# -------------------------  -------
# all                              1
# sbs_preprocess_gen_cppipe        1
# total                            2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 15:09:32 2025]
# localrule sbs_preprocess_gen_cppipe:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/preprocess/completed.txt
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/preprocess/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight preprocess cppipe -l /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/preprocess -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/preprocess -w /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs -b /home/ank/workspace/hub/broad/starrynight/scratch/starrynight_example_input/workspace/metadata/barcode.csv -n DAPI --use_legacy
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/preprocess/completed.txt.
# [Thu May 15 15:09:35 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 15:09:35 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/preprocess/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 15:09:35 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T150932.558458.snakemake.log

# %% [markdown]
# ### Invoke cppipe file

# %%
sbs_preprocess_invoke_mod = SBSPreprocessInvokeCPModule(
    data_config, pcp_experiment
)
# Add the CP plugin directory
sbs_preprocess_invoke_mod.spec.inputs["plugin_path"] = "/home/ank/workspace/hub/broad/starrynight/scratch/CellProfiler-plugins/active_plugins/"

exec_backend = SnakeMakeBackend(
    sbs_preprocess_invoke_mod.pipe,
    backend_config,
    exec_runs / "run020",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# ------------------------------------------------------------------
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                         count
# ------------------------  -------
# all                             1
# sbs_preprocess_invoke_cp        1
# total                           2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 15:09:38 2025]
# localrule sbs_preprocess_invoke_cp:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/preprocess/completed.txt, /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/preprocess/completed.txt, /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/completed.txt
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight cp -p /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/sbs/preprocess/preprocess_sbs.cppipe -l /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/sbs/preprocess -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs --sbs --plugin_dir /home/ank/workspace/hub/broad/starrynight/scratch/CellProfiler-plugins/active_plugins/
# INFO:cellprofiler_core.utilities.java:Initializing Java Virtual Machine
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]Could not load runomnipose
# Could not load runomnipose
# Could not load runstardist
# Could not load runstardist
# Could not load runomnipose
# Could not load runstardist
# [ERROR] "loci.formats.in.WlzReader" is not valid.
# [ERROR] "loci.formats.in.WlzReader" is not valid.
# [ERROR] "loci.formats.in.WlzReader" is not valid.
# [ERROR] "loci.formats.in.IonpathMIBITiffReader" is not valid.
# [ERROR] "loci.formats.in.IonpathMIBITiffReader" is not valid.
# [ERROR] "loci.formats.in.IonpathMIBITiffReader" is not valid.
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle03_DAPI.tiff
# Reading IFDs
# Populating metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle02_T.tiff
# Checking comment style
# Populating OME metadata
# Reading IFDs
# Populating metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle03_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle02_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle02_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle01_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:441: RuntimeWarning: invalid value encountered in divide
#   cmi_x[lindexes - 1] = i_x / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:442: RuntimeWarning: invalid value encountered in divide
#   cmi_y[lindexes - 1] = i_y / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:443: RuntimeWarning: invalid value encountered in divide
#   cmi_z[lindexes - 1] = i_z / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:441: RuntimeWarning: invalid value encountered in divide
#   cmi_x[lindexes - 1] = i_x / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:442: RuntimeWarning: invalid value encountered in divide
#   cmi_y[lindexes - 1] = i_y / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:443: RuntimeWarning: invalid value encountered in divide
#   cmi_z[lindexes - 1] = i_z / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:441: RuntimeWarning: invalid value encountered in divide
#   cmi_x[lindexes - 1] = i_x / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:442: RuntimeWarning: invalid value encountered in divide
#   cmi_y[lindexes - 1] = i_y / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:443: RuntimeWarning: invalid value encountered in divide
#   cmi_z[lindexes - 1] = i_z / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle02_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle02_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle02_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle02_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle03_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle03_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle03_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle03_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle03_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle02_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle01_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle01_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle01_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle01_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle02_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle02_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle02_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle02_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle03_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle03_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle03_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle03_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle03_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle02_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle01_DAPI.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/sbs/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle02_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle02_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle02_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle02_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle03_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle03_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle03_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle03_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
#
#
# 100%|██████████| 1/1 [00:55<00:00, 55.55s/it]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
#
# 100%|██████████| 1/1 [00:56<00:00, 56.51s/it]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle01_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle01_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle01_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle01_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle02_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle02_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle02_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle02_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle03_A.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle03_C.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle03_G.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle03_T.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# 100%|██████████| 1/1 [00:58<00:00, 58.21s/it]
# INFO:cellprofiler_core.utilities.java:Shutting down Java Virtual Machine
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1
# self.csv_path: /home/ank/workspace/hub/broad/starrynight/scratch/starrynight_example_input/workspace/metadata/barcode.csv
# self.csv_path: /home/ank/workspace/hub/broad/starrynight/scratch/starrynight_example_input/workspace/metadata/barcode.csv
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2
# self.csv_path: /home/ank/workspace/hub/broad/starrynight/scratch/starrynight_example_input/workspace/metadata/barcode.csv
# self.csv_path: /home/ank/workspace/hub/broad/starrynight/scratch/starrynight_example_input/workspace/metadata/barcode.csv
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1
# self.csv_path: /home/ank/workspace/hub/broad/starrynight/scratch/starrynight_example_input/workspace/metadata/barcode.csv
# self.csv_path: /home/ank/workspace/hub/broad/starrynight/scratch/starrynight_example_input/workspace/metadata/barcode.csv
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/completed.txt.
# [Thu May 15 15:10:41 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 15:10:41 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 15:10:41 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T150938.896230.snakemake.log

# %% [markdown]
# ## Step 9: Analysis

# %% [markdown]
# ### Gen load data

# %%
analysis_load_data_mod = AnalysisGenLoadDataModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
analysis_load_data_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    analysis_load_data_mod.pipe,
    backend_config,
    exec_runs / "run021",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                      count
# ---------------------  -------
# all                          1
# analysis_gen_loaddata        1
# total                        2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 16:39:02 2025]
# localrule analysis_gen_loaddata:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index/index.parquet
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/analysis/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight analysis loaddata -i /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/index/index.parquet -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/analysis --corr_images /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply --comp_images /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs --use_legacy --exp_config /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/experiment/experiment.json
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/analysis/completed.txt.
# [Thu May 15 16:39:04 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 16:39:04 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/analysis/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 16:39:04 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T163902.210708.snakemake.log

# %% [markdown]
# ### Gen cppipe file

# %%
analysis_cppipe_mod = AnalysisGenCPPipeModule(
    data_config, pcp_experiment
)

# Change default value to use legacy pipeline compatible load data
analysis_cppipe_mod.spec.inputs["use_legacy"].value = True

exec_backend = SnakeMakeBackend(
    analysis_cppipe_mod.pipe,
    backend_config,
    exec_runs / "run022",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                    count
# -------------------  -------
# all                        1
# analysis_gen_cppipe        1
# total                      2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 16:20:44 2025]
# localrule analysis_gen_cppipe:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/analysis/completed.txt
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/analysis/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight analysis cppipe -l /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/analysis -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/analysis -w /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis -b /home/ank/workspace/hub/broad/starrynight/scratch/starrynight_example_input/workspace/metadata/barcode.csv -n DAPI -e PhalloAF750 -m ZO1AF488 --use_legacy
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/analysis/completed.txt.
# [Thu May 15 16:20:47 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 16:20:47 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/analysis/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 16:20:47 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T162044.832745.snakemake.log

# %% [markdown]
# ### Invoke cppipe file

# %%
analysis_invoke_mod = AnalysisInvokeCPModule(
    data_config, pcp_experiment
)

# Add the CP plugin directory
analysis_invoke_mod.spec.inputs["plugin_path"] = "/home/ank/workspace/hub/broad/starrynight/scratch/CellProfiler-plugins/active_plugins/"

exec_backend = SnakeMakeBackend(
    analysis_invoke_mod.pipe,
    backend_config,
    exec_runs / "run023",
    exec_mounts,
)
run = exec_backend.run()
run.wait()
# Out:
# Assuming unrestricted shared filesystem usage.
# host: GPFDA-11A
# Building DAG of jobs...
# Using shell: /nix/store/8vpg72ik2kgxfj05lc56hkqrdrfl8xi9-bash-5.2p37/bin/bash
# Provided cores: 10
# Rules claiming more threads will be scaled down.
# Singularity containers: ignored
# Job stats:
# job                   count
# ------------------  -------
# all                       1
# analysis_invoke_cp        1
# total                     2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 16:39:45 2025]
# localrule analysis_invoke_cp:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/analysis/completed.txt, /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/analysis/completed.txt, /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/completed.txt, /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/segmentation/cp/segcheck/completed.txt
#     output: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/completed.txt
#     jobid: 1
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# starrynight cp -p /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/cppipe/analysis/analysis.cppipe -l /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/cellprofiler/loaddata/analysis -o /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis --plugin_dir /home/ank/workspace/hub/broad/starrynight/scratch/CellProfiler-plugins/active_plugins/
# INFO:cellprofiler_core.utilities.java:Initializing Java Virtual Machine
# SLF4J: No SLF4J providers were found.
# SLF4J: Defaulting to no-operation (NOP) logger implementation
# SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
# SLF4J: Class path contains SLF4J bindings targeting slf4j-api versions 1.7.x or earlier.
# SLF4J: Ignoring binding found at [jar:file:/home/ank/.jgo/ome/formats-gpl/RELEASE/26ef63f47acfa371a7f7390693be2d5f68f00395d7cb8d45dc49541112fccb61/logback-classic-1.2.3.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See https://www.slf4j.org/codes.html#ignoredBindings for an explanation.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#   0%|          | 0/1 [00:00<?, ?it/s]Could not load runomnipose
# Could not load runstardist
# Morph's 'Life' option has been removed, this pipeline might not be compatible with the current version of CellProfiler.
# Could not load runomnipose
# Could not load runstardist
# Morph's 'Life' option has been removed, this pipeline might not be compatible with the current version of CellProfiler.
# Could not load runomnipose
# Could not load runstardist
# Morph's 'Life' option has been removed, this pipeline might not be compatible with the current version of CellProfiler.
# Experiment-wide values for mean threshold, etc calculated by MeasureImageQuality may be incorrect if the run is split into subsets of images.
# Experiment-wide values for mean threshold, etc calculated by MeasureImageQuality may be incorrect if the run is split into subsets of images.
# Experiment-wide values for mean threshold, etc calculated by MeasureImageQuality may be incorrect if the run is split into subsets of images.
# [ERROR] "loci.formats.in.WlzReader" is not valid.
# [ERROR] "loci.formats.in.IonpathMIBITiffReader" is not valid.
# [ERROR] "loci.formats.in.WlzReader" is not valid.
# [ERROR] "loci.formats.in.IonpathMIBITiffReader" is not valid.
# [ERROR] "loci.formats.in.WlzReader" is not valid.
# [ERROR] "loci.formats.in.IonpathMIBITiffReader" is not valid.
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_CorrPhalloidin.tiff
# Reading IFDs
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_CorrPhalloidin.tiff
# Populating metadata
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_CorrPhalloidin.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_CorrDNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_CorrZO1.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_CorrDNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_CorrZO1.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_CorrDNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_0_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_CorrZO1.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1025_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3075_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: divide by zero encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: divide by zero encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: invalid value encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: divide by zero encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: invalid value encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:441: RuntimeWarning: invalid value encountered in divide
#   cmi_x[lindexes - 1] = i_x / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:442: RuntimeWarning: invalid value encountered in divide
#   cmi_y[lindexes - 1] = i_y / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:443: RuntimeWarning: invalid value encountered in divide
#   cmi_z[lindexes - 1] = i_z / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:441: RuntimeWarning: invalid value encountered in divide
#   cmi_x[lindexes - 1] = i_x / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:442: RuntimeWarning: invalid value encountered in divide
#   cmi_y[lindexes - 1] = i_y / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:443: RuntimeWarning: invalid value encountered in divide
#   cmi_z[lindexes - 1] = i_z / integrated_intensity[lindexes - 1]
# /home/ank/workspace/hub/broad/starrynight/scratch/CellProfiler-plugins/active_plugins/callbarcodes.py:550: RuntimeWarning: invalid value encountered in divide
#   score_per_obj = max_per_obj / sum_per_obj
# /home/ank/workspace/hub/broad/starrynight/scratch/CellProfiler-plugins/active_plugins/callbarcodes.py:550: RuntimeWarning: invalid value encountered in divide
#   score_per_obj = max_per_obj / sum_per_obj
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:441: RuntimeWarning: invalid value encountered in divide
#   cmi_x[lindexes - 1] = i_x / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:442: RuntimeWarning: invalid value encountered in divide
#   cmi_y[lindexes - 1] = i_y / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:443: RuntimeWarning: invalid value encountered in divide
#   cmi_z[lindexes - 1] = i_z / integrated_intensity[lindexes - 1]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:982: RuntimeWarning: invalid value encountered in divide
#   scipy.ndimage.sum(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:991: RuntimeWarning: invalid value encountered in divide
#   (
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:1002: RuntimeWarning: invalid value encountered in divide
#   scipy.ndimage.sum(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:982: RuntimeWarning: invalid value encountered in divide
#   scipy.ndimage.sum(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:991: RuntimeWarning: invalid value encountered in divide
#   (
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:1002: RuntimeWarning: invalid value encountered in divide
#   scipy.ndimage.sum(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:377: RuntimeWarning: invalid value encountered in divide
#   integrated_intensity[lindexes - 1] / lcount
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/scipy/ndimage/_measurements.py:805: RuntimeWarning: invalid value encountered in divide
#   return sum / np.asanyarray(count).astype(np.float64)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:520: RuntimeWarning: invalid value encountered in divide
#   integrated_intensity_edge[lindexes - 1] / ecount
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:377: RuntimeWarning: invalid value encountered in divide
#   integrated_intensity[lindexes - 1] / lcount
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/scipy/ndimage/_measurements.py:805: RuntimeWarning: invalid value encountered in divide
#   return sum / np.asanyarray(count).astype(np.float64)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:520: RuntimeWarning: invalid value encountered in divide
#   integrated_intensity_edge[lindexes - 1] / ecount
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:735: RuntimeWarning: invalid value encountered in divide
#   x * y / (std1[labels - 1] * std2[labels - 1]), labels, lrange
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:982: RuntimeWarning: invalid value encountered in divide
#   scipy.ndimage.sum(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:991: RuntimeWarning: invalid value encountered in divide
#   (
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measurecolocalization.py:1002: RuntimeWarning: invalid value encountered in divide
#   scipy.ndimage.sum(
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:377: RuntimeWarning: invalid value encountered in divide
#   integrated_intensity[lindexes - 1] / lcount
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/scipy/ndimage/_measurements.py:805: RuntimeWarning: invalid value encountered in divide
#   return sum / np.asanyarray(count).astype(np.float64)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/measureobjectintensity.py:520: RuntimeWarning: invalid value encountered in divide
#   integrated_intensity_edge[lindexes - 1] / ecount
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/util/dtype.py:527: UserWarning: Downcasting int32 to uint16 without scaling because max value 1101 fits in uint16
#   return _convert(image, np.uint16, force_copy)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-A1/segmentation_masks/Plate_Plate1_Well_A1_Site_0_Cells_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-A1/segmentation_masks/Plate_Plate1_Well_A1_Site_0_Cytoplasm_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-A1/segmentation_masks/Plate_Plate1_Well_A1_Site_0_Nuclei_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_CorrPhalloidin.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_CorrDNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_CorrZO1.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A1/Plate_Plate1_Well_A1_Site_1_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_CorrPhalloidin.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/util/dtype.py:527: UserWarning: Downcasting int32 to uint16 without scaling because max value 1049 fits in uint16
#   return _convert(image, np.uint16, force_copy)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-A2/segmentation_masks/Plate_Plate1_Well_A2_Site_1025_Cells_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-A2/segmentation_masks/Plate_Plate1_Well_A2_Site_1025_Cytoplasm_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-A2/segmentation_masks/Plate_Plate1_Well_A2_Site_1025_Nuclei_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_CorrDNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_CorrZO1.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-A2/Plate_Plate1_Well_A2_Site_1026_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler_core/modules/align.py:526: RuntimeWarning: invalid value encountered in divide
#   corrnorm = corr12 / sd
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/util/dtype.py:527: UserWarning: Downcasting int32 to uint16 without scaling because max value 1364 fits in uint16
#   return _convert(image, np.uint16, force_copy)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-B1/segmentation_masks/Plate_Plate1_Well_B1_Site_3075_Cells_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-B1/segmentation_masks/Plate_Plate1_Well_B1_Site_3075_Cytoplasm_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-B1/segmentation_masks/Plate_Plate1_Well_B1_Site_3075_Nuclei_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_CorrPhalloidin.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle01_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle03_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle01_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle02_C.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle02_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle01_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle03_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle02_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle01_DNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle02_A.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle03_G.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_CorrDNA.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/illum/cp/illum_apply/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_CorrZO1.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle01_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# TiffDelegateReader initializing /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/preprocess/sbs/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_Cycle03_T.tiff
# Reading IFDs
# Populating metadata
# Checking comment style
# Populating OME metadata
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-B1/Plate_Plate1_Well_B1_Site_3076_CorrDNA_Overlay.png is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/util/dtype.py:527: UserWarning: Downcasting int32 to uint16 without scaling because max value 1 fits in uint16
#   return _convert(image, np.uint16, force_copy)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-B1/segmentation_masks/Plate_Plate1_Well_B1_Site_3076_Cells_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-B1/segmentation_masks/Plate_Plate1_Well_B1_Site_3076_Cytoplasm_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-B1/segmentation_masks/Plate_Plate1_Well_B1_Site_3076_Nuclei_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
#
#
# 100%|██████████| 1/1 [01:38<00:00, 98.53s/it]
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/util/dtype.py:527: UserWarning: Downcasting int32 to uint16 without scaling because max value 1087 fits in uint16
#   return _convert(image, np.uint16, force_copy)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-A2/segmentation_masks/Plate_Plate1_Well_A2_Site_1026_Cells_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-A2/segmentation_masks/Plate_Plate1_Well_A2_Site_1026_Cytoplasm_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-A2/segmentation_masks/Plate_Plate1_Well_A2_Site_1026_Nuclei_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/skimage/util/dtype.py:527: UserWarning: Downcasting int32 to uint16 without scaling because max value 1114 fits in uint16
#   return _convert(image, np.uint16, force_copy)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-A1/segmentation_masks/Plate_Plate1_Well_A1_Site_1_Cells_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-A1/segmentation_masks/Plate_Plate1_Well_A1_Site_1_Cytoplasm_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
# /nix/store/iwzgzi8nwnalq6g4rmf5fjl01mg5p55j-python3-3.11.11-env/lib/python3.11/site-packages/cellprofiler/modules/saveimages.py:795: UserWarning: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-A1/segmentation_masks/Plate_Plate1_Well_A1_Site_1_Nuclei_Objects.tiff is a low contrast image
#   skimage.io.imsave(filename, pixels, **save_kwargs)
#
# 100%|██████████| 1/1 [01:53<00:00, 113.09s/it]
# 100%|██████████| 1/1 [01:54<00:00, 114.37s/it]
# INFO:cellprofiler_core.utilities.java:Shutting down Java Virtual Machine
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-B1
# self.csv_path: /home/ank/workspace/hub/broad/starrynight/scratch/starrynight_example_input/workspace/metadata/barcode.csv
# self.csv_path: /home/ank/workspace/hub/broad/starrynight/scratch/starrynight_example_input/workspace/metadata/barcode.csv
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-A2
# self.csv_path: /home/ank/workspace/hub/broad/starrynight/scratch/starrynight_example_input/workspace/metadata/barcode.csv
# self.csv_path: /home/ank/workspace/hub/broad/starrynight/scratch/starrynight_example_input/workspace/metadata/barcode.csv
# /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/Batch1-Plate1-A1
# self.csv_path: /home/ank/workspace/hub/broad/starrynight/scratch/starrynight_example_input/workspace/metadata/barcode.csv
# self.csv_path: /home/ank/workspace/hub/broad/starrynight/scratch/starrynight_example_input/workspace/metadata/barcode.csv
# Touching output file /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/completed.txt.
# [Thu May 15 16:41:43 2025]
# Finished job 1.
# 1 of 2 steps (50%) done
# Select jobs to execute...
# Execute 1 jobs...
#
# [Thu May 15 16:41:43 2025]
# localrule all:
#     input: /home/ank/workspace/hub/broad/starrynight/scratch/new_starrynight_example_output/analysis/completed.txt
#     jobid: 0
#     reason: Forced execution
#     resources: tmpdir=/tmp
#
# echo 'done' > completed.txt
# [Thu May 15 16:41:43 2025]
# Finished job 0.
# 2 of 2 steps (100%) done
# Complete log: .snakemake/log/2025-05-15T163945.079731.snakemake.log
